# %% [markdown]
# # <span style="background-color:#005e81; padding:5px; border-radius:5px;">**contracts_2009_2024**</span>

# %%
# !pip install scipy
# !pip install scikit-learn
# !pip install umap-learn
# !pip install statsmodels
# !pip install scikit-posthocs
# !pip install pyarrow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from collections import OrderedDict
from datetime import date
import ast
from itertools import zip_longest
from scipy.stats import kstest, norm
from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
import math
from sklearn.manifold import TSNE
import umap
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
from scipy import stats
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import accuracy_score
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import scipy.stats as sps
import scikit_posthocs as sp
import seaborn as sns
from matplotlib.ticker import FuncFormatter, MultipleLocator, MaxNLocator

# %%
palette_pastel = [
    "#0d86b3",  # azul pastel
    "#96EE9C",  # verde pastel
    "#B271DE",  # roxo pastel
    "#F6B361",  # laranja pastel
    "#FA84E8",  # rosa pastel
    "#8A6F52"   # castanho pastel
]

# %%
contracts_2009_2024 = pd.read_parquet("C:/Users/beatr/Desktop/NOVA IMS/Bolsa de Investigação/RISKGUARD/contracts_2009_2024.parquet")
contracts_2009_2024
# Out:
#              id  contract_id  \
# 0             1        94221
# 1             2        74464
# 2             3       123257
# 3             4       132120
# 4             5        66521
# ...         ...          ...
# 1931285  204456     11097971
# 1931286  204461     10813424
# 1931287  204474     10813480
# 1931288  204480     10813483
# 1931289  204482     11043018
#
#                                                contestants  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 1931285                                               None
# 1931286  [{'description': 'ECOAMBIENTE - SERVIÇOS E MEI...
# 1931287  [{'description': 'Dolce Far Niente Lda', 'nif'...
# 1931288                                               None
# 1931289  [{'description': 'Margem Mítica-Manutenção e R...
#
#                                                 contracted  \
# 0        [{'description': 'CESPA Portugal, S.A.', 'nif'...
# 1        [{'description': 'Salemo & Merca, Lda.', 'nif'...
# 2        [{'description': 'Jorge, Vitor, Neto, Fernande...
# 3        [{'description': 'Instituto Politécnico de Lei...
# 4        [{'description': 'LGT TELECOMUNICAÇÕES E ELECT...
# ...                                                    ...
# 1931285  [{'description': 'Mind Software Multimédia Ind...
# 1931286  [{'description': 'JUSTACOLINA- SERVIÇOS DE SIL...
# 1931287  [{'description': 'Dolce Far Niente Turismo e E...
# 1931288  [{'description': 'Teva Pharma - Produtos Farma...
# 1931289  [{'description': 'Margarida Braz Borges Unipes...
#
#                          contract_type  \
# 0                Aquisição de serviços
# 1             Aquisição de bens móveis
# 2                Aquisição de serviços
# 3                Aquisição de serviços
# 4             Aquisição de bens móveis
# ...                                ...
# 1931285          Aquisição de serviços
# 1931286          Aquisição de serviços
# 1931287          Aquisição de serviços
# 1931288       Aquisição de bens móveis
# 1931289  Empreitadas de obras públicas
#
#                                                  documents invitees  \
# 0                                                     None     None
# 1                                                     None     None
# 2                                                     None     None
# 3                                                     None     None
# 4                                                     None     None
# ...                                                    ...      ...
# 1931285  [{'description': 'Contrato_152_2024.pdf', 'id'...     None
# 1931286  [{'description': 'CP-2024-06_DOP - contrato_Lo...     None
# 1931287  [{'description': 'contrato 53_Ocultado.pdf', '...     None
# 1931288                                               None     None
# 1931289  [{'description': '1032-24 - 7212132.pdf', 'id'...     None
#
#         centralized_procedure              procedure_type  \
# 0                        None  Ajuste Direto Regime Geral
# 1                        None  Ajuste Direto Regime Geral
# 2                        None  Ajuste Direto Regime Geral
# 3                        None  Ajuste Direto Regime Geral
# 4                        None  Ajuste Direto Regime Geral
# ...                       ...                         ...
# 1931285                 False  Ajuste Direto Regime Geral
# 1931286                 False            Concurso público
# 1931287                 False  Ajuste Direto Regime Geral
# 1931288                 False  Ajuste Direto Regime Geral
# 1931289                 False            Concurso público
#
#                                         contracting_agency  ...        cpvs  \
# 0        [{'description': 'Município de Setúbal', 'nif'...  ...  50000000-5
# 1        [{'description': 'Lagos em Forma, Gestão Despo...  ...  44212310-5
# 2        [{'description': 'Município de Resende', 'nif'...  ...  79212500-8
# 3        [{'description': 'Instituto da Conservação da ...  ...  92222000-3
# 4        [{'description': 'Estado Maior do Exército', '...  ...  30231000-7
# ...                                                    ...  ...         ...
# 1931285  [{'description': 'MUNICÍPIO DA MARINHA GRANDE'...  ...  72267100-0
# 1931286  [{'description': 'AdRA - Águas da Região de Av...  ...  77314000-4
# 1931287  [{'description': 'Município de Sabrosa', 'nif'...  ...  92310000-7
# 1931288  [{'description': 'Unidade Local de Saúde de Sa...  ...  33600000-6
# 1931289  [{'description': 'Município de Sintra', 'nif':...  ...  45211310-5
#
#         execution_deadline                                 execution_location  \
# 0                       15  [{'country': 'Portugal', 'district': 'Setubal'...
# 1                       60  [{'country': 'Portugal', 'district': 'Faro', '...
# 2                      730  [{'country': 'Portugal', 'district': 'Viseu', ...
# 3                       40  [{'country': 'Portugal', 'district': 'Santarem...
# 4                       45  [{'country': 'Portugal', 'district': 'Santarem...
# ...                    ...                                                ...
# 1931285               1095  [{'country': 'Portugal', 'district': 'Leiria',...
# 1931286                630  [{'country': 'Portugal', 'district': 'Aveiro',...
# 1931287                  1  [{'country': 'Portugal', 'district': 'Vila Rea...
# 1931288                 30  [{'country': 'Portugal', 'district': 'Porto', ...
# 1931289                 15  [{'country': 'Portugal', 'district': 'Lisboa',...
#
#          initial_price final_price  signing_date  environmental_criteria  \
# 0              9613.74         NaN    2009-10-15                   False
# 1              6457.20      6457.2    2009-06-23                   False
# 2             10000.00     10000.0    2009-12-15                   False
# 3              5600.00         NaN    2009-11-09                   False
# 4             10325.68         NaN    2009-07-02                   False
# ...                ...         ...           ...                     ...
# 1931285       59535.00         NaN    2024-12-13                   False
# 1931286      199000.00         NaN    2024-07-09                    True
# 1931287       10250.00     10250.0    2024-07-08                   False
# 1931288      188370.00         NaN    2024-03-21                   False
# 1931289        2000.00         NaN    2024-11-08                   False
#
#         material_criteria  causes_deadline_change  causes_price_change
# 0                   False                    None                 None
# 1                   False                    None                 None
# 2                   False                    None                 None
# 3                   False                    None                 None
# 4                   False                    None                 None
# ...                   ...                     ...                  ...
# 1931285             False                    None                 None
# 1931286             False                    None                 None
# 1931287             False                    None                 None
# 1931288              True                    None                 None
# 1931289             False                    None                 None
#
# [1931290 rows x 22 columns]

# %% [markdown]
# ## <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Functions**</span> <a id='Data-Types'></a>

# %%
#this function will be reuse to format the axis

def format_func(value, tick_number):
    if value == 0:
        return '0'
    elif value < 1:
        return f'{value:.2f}'
    else:
        return f'{value:.0f}'

# %%
def plot_histograms(data, columns, num_rows, num_cols, show_kde=True):
    total_plots = len(columns)
    fig, axs = plt.subplots(num_rows, num_cols, figsize=(18, 3 * num_rows))
    axs = axs.flatten() if num_rows * num_cols > 1 else [axs]  

    for i, col in enumerate(columns):
        if i < len(axs):  
            
            sns.histplot(data[col], bins=50, kde=show_kde, ax=axs[i], color=palette_pastel[0])  
            axs[i].set_title(f'Distribution of {col}')
            axs[i].set_xlabel(col)
            axs[i].set_ylabel('Count')
            axs[i].grid(color='lightgray', alpha=0.2)
            axs[i].xaxis.set_major_formatter(FuncFormatter(format_func))
            
            max_value = data[col].dropna().max()
            if np.isfinite(max_value):
                if max_value <= 1:
                    axs[i].xaxis.set_major_locator(MultipleLocator(0.1))  
                elif max_value <= 30:
                    axs[i].xaxis.set_major_locator(MultipleLocator(1))
                elif max_value <= 70:
                    axs[i].xaxis.set_major_locator(MultipleLocator(2)) 
                elif max_value <= 120:
                    axs[i].xaxis.set_major_locator(MultipleLocator(5))  
                else:
                    axs[i].xaxis.set_major_locator(MaxNLocator(integer=True)) 

                axs[i].set_xlim(0, max_value) 
            else:
                axs[i].set_xlim(0, 1)  

            plt.setp(axs[i].get_xticklabels(), rotation=0)

    for j in range(len(columns), num_rows * num_cols):
        fig.delaxes(axs[j])

    plt.tight_layout()
    plt.show()

# %%
def plot_boxplots(data, columns, num_rows, num_cols):
    total_plots = len(columns)
    fig, axs = plt.subplots(num_rows, num_cols, figsize=(18, 2 * num_rows))
    axs = axs.flatten() if num_rows * num_cols > 1 else [axs]  

    stats = [] 

    for i, col in enumerate(columns):
        if i < len(axs):  
            # Create the boxplot
            boxplot = sns.boxplot(x=data[col], ax=axs[i], color=palette_pastel[0])  

            # Apply alpha to the boxplot elements
            for patch in boxplot.patches:
                patch.set_alpha(0.5)

            axs[i].set_title(f'Distribution of {col}')
            axs[i].set_xlabel(col)  
            axs[i].set_ylabel('')  
            axs[i].grid(color='lightgray', alpha=0.2)

            axs[i].xaxis.set_major_formatter(FuncFormatter(format_func))
            max_value = data[col].dropna().max() 
            if np.isfinite(max_value):
                axs[i].set_xlim(0, max_value)  
            else:
                axs[i].set_xlim(0, 1)  

            # IQR statistics
            q1 = data[col].quantile(0.25)
            median = data[col].median()
            q3 = data[col].quantile(0.75)
            iqr = q3 - q1
            lower_fence = q1 - 1.5 * iqr
            upper_fence = q3 + 1.5 * iqr
            min_val = data[col].min()
            max_val = data[col].max()
            stats.append([col, min_val, lower_fence, q1, median, q3, upper_fence, max_val])
            
    for j in range(len(columns), num_rows * num_cols):
        fig.delaxes(axs[j])

    plt.tight_layout()
    plt.show()

    return pd.DataFrame(stats, columns=['Variable', 'Min', 'Lower Fence', 'Q1', 'Median', 'Q3', 'Upper Fence', 'Max'])

# %% [markdown]
# ## <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Preprocessing**</span> <a id='Data-Types'></a>

# %%
contracts_2009_2024["procedure_type"].value_counts(dropna=False)
# Out:
# procedure_type
# Ajuste Direto Regime Geral                                                        1284302
# Consulta Prévia                                                                    249122
# Concurso público                                                                   197182
# Ao abrigo de acordo-quadro (art.º 259.º)                                           155463
# Ao abrigo de acordo-quadro (art.º 258.º)                                            36836
# Concurso limitado por prévia qualificação                                            3495
# Contratação excluída II                                                              2765
# Consulta Prévia Simplificada                                                         1202
# Setores especiais – isenção parte II                                                  710
# Procedimento de negociação                                                             94
# Concurso público simplificado                                                          56
# Consulta prévia ao abrigo do artigo 7º da Lei n.º 30/2021, de 21.05                    27
# Ajuste Direto Regime Geral ao abrigo do artigo 7º da Lei n.º 30/2021, de 21.05         18
# Serviços sociais e outros serviços específicos                                          9
# Concurso de conceção simplificado                                                       5
# Parceria para a inovação                                                                2
# None                                                                                    1
# Concurso de ideias simplificado                                                         1
# Name: count, dtype: int64

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**procedure_type**</span> <a id='Data-Types'></a>

# %% [markdown]
# Vamos só considerar `Concurso Público`:

# %%
concursos_publicos = contracts_2009_2024[contracts_2009_2024["procedure_type"] == 'Concurso público']
concursos_publicos
# Out:
#              id  contract_id  \
# 21           72       113748
# 165          68        83773
# 276        1811       617382
# 432         172       131965
# 531         195        87178
# ...         ...          ...
# 1931274  204444     11088869
# 1931281  204436     11088891
# 1931283  204443     11088904
# 1931286  204461     10813424
# 1931289  204482     11043018
#
#                                                contestants  \
# 21                                                    None
# 165                                                   None
# 276                                                   None
# 432                                                   None
# 531                                                   None
# ...                                                    ...
# 1931274  [{'description': 'Carl Zeiss Iberia S.L.', 'ni...
# 1931281  [{'description': 'Servilimpe Limpezas Técnicas...
# 1931283  [{'description': 'Exemplus Internacional Ldª',...
# 1931286  [{'description': 'ECOAMBIENTE - SERVIÇOS E MEI...
# 1931289  [{'description': 'Margem Mítica-Manutenção e R...
#
#                                                 contracted  \
# 21       [{'description': 'MECH - Engenheiros Associado...
# 165      [{'description': 'Gertal - Companhia de Restau...
# 276      [{'description': 'Gonçalves & Cachadinha, SA',...
# 432      [{'description': 'FCTUNL - Faculdade Ciências ...
# 531      [{'description': 'Hobbyvida-Serviços Desportiv...
# ...                                                    ...
# 1931274  [{'description': 'Carl Zeiss Iberia S.L.', 'ni...
# 1931281  [{'description': 'Fine Facility Services', 'ni...
# 1931283  [{'description': 'Multitendas-Comércio e Alugu...
# 1931286  [{'description': 'JUSTACOLINA- SERVIÇOS DE SIL...
# 1931289  [{'description': 'Margarida Braz Borges Unipes...
#
#                          contract_type  \
# 21               Aquisição de serviços
# 165              Aquisição de serviços
# 276      Empreitadas de obras públicas
# 432              Aquisição de serviços
# 531              Aquisição de serviços
# ...                                ...
# 1931274       Aquisição de bens móveis
# 1931281          Aquisição de serviços
# 1931283         Locação de bens móveis
# 1931286          Aquisição de serviços
# 1931289  Empreitadas de obras públicas
#
#                                                  documents invitees  \
# 21                                                    None     None
# 165                                                   None     None
# 276                                                   None     None
# 432                                                   None     None
# 531                                                   None     None
# ...                                                    ...      ...
# 1931274  [{'description': 'BaseGov_Contrato_CP_02_2024_...     None
# 1931281  [{'description': '3024012666 20241210 - CONTRA...     None
# 1931283  [{'description': 'Multitendas Expurgado.pdf', ...     None
# 1931286  [{'description': 'CP-2024-06_DOP - contrato_Lo...     None
# 1931289  [{'description': '1032-24 - 7212132.pdf', 'id'...     None
#
#         centralized_procedure    procedure_type  \
# 21                       None  Concurso público
# 165                      None  Concurso público
# 276                      None  Concurso público
# 432                      None  Concurso público
# 531                      None  Concurso público
# ...                       ...               ...
# 1931274                 False  Concurso público
# 1931281                  True  Concurso público
# 1931283                 False  Concurso público
# 1931286                 False  Concurso público
# 1931289                 False  Concurso público
#
#                                         contracting_agency  ...        cpvs  \
# 21       [{'description': 'Instituto da Habitação e da ...  ...  71322000-1
# 165      [{'description': 'Município de Vila Pouca de A...  ...  55524000-9
# 276      [{'description': 'Município de Arcos de Valdev...  ...  45233251-3
# 432      [{'description': 'Agência Portuguesa do Ambien...  ...  90710000-7
# 531      [{'description': 'Município de Abrantes', 'nif...  ...  80000000-4
# ...                                                    ...  ...         ...
# 1931274  [{'description': 'UNL - Faculdade de Ciências ...  ...  38515200-0
# 1931281  [{'description': 'Ministério da Defesa Naciona...  ...  90910000-9
# 1931283  [{'description': 'Município de Braga', 'nif': ...  ...  39300000-5
# 1931286  [{'description': 'AdRA - Águas da Região de Av...  ...  77314000-4
# 1931289  [{'description': 'Município de Sintra', 'nif':...  ...  45211310-5
#
#         execution_deadline                                 execution_location  \
# 21                      75  [{'country': 'Portugal', 'district': 'Setubal'...
# 165                    300  [{'country': 'Portugal', 'district': 'Vila Rea...
# 276                    200  [{'country': 'Portugal', 'district': 'Viana do...
# 432                    365  [{'country': 'Portugal', 'district': 'Lisboa',...
# 531                    174  [{'country': 'Portugal', 'district': 'Santarem...
# ...                    ...                                                ...
# 1931274                121  [{'country': 'Portugal', 'district': 'Lisboa',...
# 1931281                912  [{'country': 'Portugal', 'district': 'Setubal'...
# 1931283                182  [{'country': 'Portugal', 'district': 'Braga', ...
# 1931286                630  [{'country': 'Portugal', 'district': 'Aveiro',...
# 1931289                 15  [{'country': 'Portugal', 'district': 'Lisboa',...
#
#          initial_price final_price  signing_date  environmental_criteria  \
# 21            25000.00         NaN    2009-12-04                   False
# 165          140077.08         NaN    2009-09-11                   False
# 276          699097.05   706538.62    2009-07-17                   False
# 432          133000.00         NaN    2009-07-30                   False
# 531           53935.00    51922.50    2009-09-11                   False
# ...                ...         ...           ...                     ...
# 1931274      510000.00         NaN    2024-12-10                   False
# 1931281        6182.64         NaN    2024-05-29                   False
# 1931283      529612.45         NaN    2024-12-11                   False
# 1931286      199000.00         NaN    2024-07-09                    True
# 1931289        2000.00         NaN    2024-11-08                   False
#
#         material_criteria                             causes_deadline_change  \
# 21                  False                                               None
# 165                 False                                               None
# 276                 False  Problemas de logística e de tesouraria do adju...
# 432                 False                                               None
# 531                 False                                               None
# ...                   ...                                                ...
# 1931274             False                                               None
# 1931281             False                                               None
# 1931283             False                                               None
# 1931286             False                                               None
# 1931289             False                                               None
#
#                                        causes_price_change
# 21                                                    None
# 165                                                   None
# 276      As alterações no valor de obra, resultam do fa...
# 432                                                   None
# 531      Estava prevista a frequência de todos os aluno...
# ...                                                    ...
# 1931274                                               None
# 1931281                                               None
# 1931283                                               None
# 1931286                                               None
# 1931289                                               None
#
# [197182 rows x 22 columns]

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Irrelevant columns**</span> <a id='Data-Types'></a>

# %% [markdown]
# We will drop the columns:
# - `invitees`, because its related to **Consulta Prévia**;
# - `procedure_type` because we are only analysing **Concurso Público**;
# - `environmental_criteria`, `material_criteria`, `documents`, `causes_deadline_change`, `causes_price_change`, `id` and `centralized_procedure` are not relevant for collusion or bid-rigging detection;
# - `close_date` have 82% of missing values;
# - `publication_date` because we will focus on the **signing_date**.

# %%
concursos_publicos.drop(columns=["invitees","procedure_type","environmental_criteria", 
                                 "material_criteria","documents","causes_deadline_change", 
                                 "causes_price_change","id","close_date", "publication_date",
                                 "centralized_procedure"], inplace=True)
concursos_publicos.shape
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_21548\4010961327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   concursos_publicos.drop(columns=["invitees","procedure_type","environmental_criteria",
# (197182, 11)

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**contestants**</span> <a id='Data-Types'></a>

# %% [markdown]
# Vamos eliminar as linhas que têm missing values na coluna `contestants`:

# %%
pct_nan = concursos_publicos["contestants"].isna().mean() * 100
print(f"% NaN/None: {pct_nan:.2f}%")
# Out:
# % NaN/None: 25.83%

# %%
concursos_publicos = concursos_publicos[concursos_publicos["contestants"].notna()]
concursos_publicos
# Out:
#          contract_id                                        contestants  \
# 73146         875874  [{'description': 'Dimor Lusitana,Lda', 'nif': ...
# 73764         148916  [{'description': 'Tomás de Oliveira Empreiteir...
# 78646        1076289  [{'description': 'TV CABO LISBOA, S.A.', 'nif'...
# 124563        136321  [{'description': 'Saniambiente Serviços Profis...
# 125322        600796  [{'description': 'De Almeida Ribeiro Empreendi...
# ...              ...                                                ...
# 1931274     11088869  [{'description': 'Carl Zeiss Iberia S.L.', 'ni...
# 1931281     11088891  [{'description': 'Servilimpe Limpezas Técnicas...
# 1931283     11088904  [{'description': 'Exemplus Internacional Ldª',...
# 1931286     10813424  [{'description': 'ECOAMBIENTE - SERVIÇOS E MEI...
# 1931289     11043018  [{'description': 'Margem Mítica-Manutenção e R...
#
#                                                 contracted  \
# 73146    [{'description': 'Medicinália Cormédica-Comerc...
# 73764    [{'description': 'MRG - ENGENHARIA E CONSTRUÇÃ...
# 78646    [{'description': 'PT PRIME - Soluções Empresar...
# 124563   [{'description': 'Euromex - Facility Services,...
# 125322   [{'description': 'Opção - Sociedade Hoteleira,...
# ...                                                    ...
# 1931274  [{'description': 'Carl Zeiss Iberia S.L.', 'ni...
# 1931281  [{'description': 'Fine Facility Services', 'ni...
# 1931283  [{'description': 'Multitendas-Comércio e Alugu...
# 1931286  [{'description': 'JUSTACOLINA- SERVIÇOS DE SIL...
# 1931289  [{'description': 'Margarida Braz Borges Unipes...
#
#                          contract_type  \
# 73146         Aquisição de bens móveis
# 73764    Empreitadas de obras públicas
# 78646            Aquisição de serviços
# 124563           Aquisição de serviços
# 125322           Aquisição de serviços
# ...                                ...
# 1931274       Aquisição de bens móveis
# 1931281          Aquisição de serviços
# 1931283         Locação de bens móveis
# 1931286          Aquisição de serviços
# 1931289  Empreitadas de obras públicas
#
#                                         contracting_agency        cpvs  \
# 73146    [{'description': 'Centro Hospitalar de Torres ...  33171000-9
# 73764    [{'description': 'VALORLIS Valorização e Trata...  45000000-7
# 78646    [{'description': 'Santa Casa da Misericórdia d...  50000000-5
# 124563   [{'description': 'Município de Torres Vedras',...  90911200-8
# 125322   [{'description': 'Municipio de Oeiras', 'nif':...  55520000-1
# ...                                                    ...         ...
# 1931274  [{'description': 'UNL - Faculdade de Ciências ...  38515200-0
# 1931281  [{'description': 'Ministério da Defesa Naciona...  90910000-9
# 1931283  [{'description': 'Município de Braga', 'nif': ...  39300000-5
# 1931286  [{'description': 'AdRA - Águas da Região de Av...  77314000-4
# 1931289  [{'description': 'Município de Sintra', 'nif':...  45211310-5
#
#          execution_deadline  \
# 73146                   240
# 73764                   150
# 78646                   365
# 124563                  365
# 125322                  365
# ...                     ...
# 1931274                 121
# 1931281                 912
# 1931283                 182
# 1931286                 630
# 1931289                  15
#
#                                         execution_location  initial_price  \
# 73146    [{'country': 'Portugal', 'district': 'Lisboa',...       15450.00
# 73764    [{'country': 'Portugal', 'district': 'Leiria',...     1794202.51
# 78646    [{'country': 'Portugal', 'district': 'Lisboa',...     9779231.25
# 124563   [{'country': 'Portugal', 'district': 'Lisboa',...      103555.17
# 125322   [{'country': 'Portugal', 'district': 'Lisboa',...      200000.00
# ...                                                    ...            ...
# 1931274  [{'country': 'Portugal', 'district': 'Lisboa',...      510000.00
# 1931281  [{'country': 'Portugal', 'district': 'Setubal'...        6182.64
# 1931283  [{'country': 'Portugal', 'district': 'Braga', ...      529612.45
# 1931286  [{'country': 'Portugal', 'district': 'Aveiro',...      199000.00
# 1931289  [{'country': 'Portugal', 'district': 'Lisboa',...        2000.00
#
#          final_price signing_date
# 73146            NaN   2010-05-12
# 73764            NaN   2010-07-30
# 78646            NaN   2010-11-25
# 124563           NaN   2010-08-16
# 125322       80655.0   2010-03-25
# ...              ...          ...
# 1931274          NaN   2024-12-10
# 1931281          NaN   2024-05-29
# 1931283          NaN   2024-12-11
# 1931286          NaN   2024-07-09
# 1931289          NaN   2024-11-08
#
# [146258 rows x 11 columns]

# %% [markdown]
# Criamos uma coluna com o número de contestants:

# %%
concursos_publicos = concursos_publicos.copy()  

concursos_publicos["number_of_contestants"] = concursos_publicos["contestants"].apply(lambda a: len(a))

# %% [markdown]
# Now, we will remove the cases that only have 1 contestant, because they are not relevant to study collusion.

# %%
concursos_publicos = concursos_publicos[concursos_publicos["number_of_contestants"] > 1].copy()
concursos_publicos
# Out:
#          contract_id                                        contestants  \
# 73146         875874  [{'description': 'Dimor Lusitana,Lda', 'nif': ...
# 73764         148916  [{'description': 'Tomás de Oliveira Empreiteir...
# 78646        1076289  [{'description': 'TV CABO LISBOA, S.A.', 'nif'...
# 124563        136321  [{'description': 'Saniambiente Serviços Profis...
# 125322        600796  [{'description': 'De Almeida Ribeiro Empreendi...
# ...              ...                                                ...
# 1931273     11088884  [{'description': 'Socodefil Lda', 'nif': '5007...
# 1931281     11088891  [{'description': 'Servilimpe Limpezas Técnicas...
# 1931283     11088904  [{'description': 'Exemplus Internacional Ldª',...
# 1931286     10813424  [{'description': 'ECOAMBIENTE - SERVIÇOS E MEI...
# 1931289     11043018  [{'description': 'Margem Mítica-Manutenção e R...
#
#                                                 contracted  \
# 73146    [{'description': 'Medicinália Cormédica-Comerc...
# 73764    [{'description': 'MRG - ENGENHARIA E CONSTRUÇÃ...
# 78646    [{'description': 'PT PRIME - Soluções Empresar...
# 124563   [{'description': 'Euromex - Facility Services,...
# 125322   [{'description': 'Opção - Sociedade Hoteleira,...
# ...                                                    ...
# 1931273  [{'description': 'Grandatlas Construções SA', ...
# 1931281  [{'description': 'Fine Facility Services', 'ni...
# 1931283  [{'description': 'Multitendas-Comércio e Alugu...
# 1931286  [{'description': 'JUSTACOLINA- SERVIÇOS DE SIL...
# 1931289  [{'description': 'Margarida Braz Borges Unipes...
#
#                          contract_type  \
# 73146         Aquisição de bens móveis
# 73764    Empreitadas de obras públicas
# 78646            Aquisição de serviços
# 124563           Aquisição de serviços
# 125322           Aquisição de serviços
# ...                                ...
# 1931273  Empreitadas de obras públicas
# 1931281          Aquisição de serviços
# 1931283         Locação de bens móveis
# 1931286          Aquisição de serviços
# 1931289  Empreitadas de obras públicas
#
#                                         contracting_agency        cpvs  \
# 73146    [{'description': 'Centro Hospitalar de Torres ...  33171000-9
# 73764    [{'description': 'VALORLIS Valorização e Trata...  45000000-7
# 78646    [{'description': 'Santa Casa da Misericórdia d...  50000000-5
# 124563   [{'description': 'Município de Torres Vedras',...  90911200-8
# 125322   [{'description': 'Municipio de Oeiras', 'nif':...  55520000-1
# ...                                                    ...         ...
# 1931273  [{'description': 'Freguesia de Avenidas Novas'...  45453100-8
# 1931281  [{'description': 'Ministério da Defesa Naciona...  90910000-9
# 1931283  [{'description': 'Município de Braga', 'nif': ...  39300000-5
# 1931286  [{'description': 'AdRA - Águas da Região de Av...  77314000-4
# 1931289  [{'description': 'Município de Sintra', 'nif':...  45211310-5
#
#          execution_deadline  \
# 73146                   240
# 73764                   150
# 78646                   365
# 124563                  365
# 125322                  365
# ...                     ...
# 1931273                 180
# 1931281                 912
# 1931283                 182
# 1931286                 630
# 1931289                  15
#
#                                         execution_location  initial_price  \
# 73146    [{'country': 'Portugal', 'district': 'Lisboa',...       15450.00
# 73764    [{'country': 'Portugal', 'district': 'Leiria',...     1794202.51
# 78646    [{'country': 'Portugal', 'district': 'Lisboa',...     9779231.25
# 124563   [{'country': 'Portugal', 'district': 'Lisboa',...      103555.17
# 125322   [{'country': 'Portugal', 'district': 'Lisboa',...      200000.00
# ...                                                    ...            ...
# 1931273  [{'country': 'Portugal', 'district': 'Lisboa',...      403966.10
# 1931281  [{'country': 'Portugal', 'district': 'Setubal'...        6182.64
# 1931283  [{'country': 'Portugal', 'district': 'Braga', ...      529612.45
# 1931286  [{'country': 'Portugal', 'district': 'Aveiro',...      199000.00
# 1931289  [{'country': 'Portugal', 'district': 'Lisboa',...        2000.00
#
#          final_price signing_date  number_of_contestants
# 73146            NaN   2010-05-12                     25
# 73764            NaN   2010-07-30                     12
# 78646            NaN   2010-11-25                      6
# 124563           NaN   2010-08-16                      3
# 125322       80655.0   2010-03-25                      3
# ...              ...          ...                    ...
# 1931273          NaN   2024-10-30                      3
# 1931281          NaN   2024-05-29                     16
# 1931283          NaN   2024-12-11                      4
# 1931286          NaN   2024-07-09                     17
# 1931289          NaN   2024-11-08                      2
#
# [132744 rows x 12 columns]

# %%
concursos_publicos.drop(columns=['number_of_contestants'], inplace=True)

# %% [markdown]
# Agora vamos verificar na coluna dos contestants, se todas as entries estão completas, ou seja, se têm description e nif:

# %%
def all_desc_and_nif(cell):
    # transformar dict isolado em lista
    if isinstance(cell, dict):
        cell = [cell]
    # se não for lista/array, considerar inválido
    if not isinstance(cell, (list, np.ndarray)):
        return False
    
    for d in cell:
        if not isinstance(d, dict):
            return False
        
        desc = d.get('description')
        nif  = d.get('nif')

        # têm de existir e não estar vazios
        if not desc or pd.isna(desc):
            return False
        if not nif or pd.isna(nif) or str(nif).strip() == "":
            return False
    return True

# máscara: linhas em que TODOS os contestants têm description e nif
mask_ok = concursos_publicos["contestants"].apply(all_desc_and_nif)

print("Linhas OK:", mask_ok.sum())
print("Linhas com problemas:", (~mask_ok).sum())

# ver os casos com problemas
problematic = concursos_publicos.loc[~mask_ok, ["contract_id", "contestants"]]
problematic
# Out:
# Linhas OK: 131826
# Linhas com problemas: 918
#          contract_id                                        contestants
# 1726811     11021616  [{'description': 'REDEMAIOR ENGENHARIA LDA', '...
# 1727163     10778987  [{'description': 'BACELAR & IRMÃO,SA', 'nif': ...
# 1727303     11011877  [{'description': 'Táxis António José Jacinto',...
# 1727661     10974879  [{'description': 'Táxis Salvado & Ramos Lda.',...
# 1728106     10827040  [{'description': 'VESTEHEROIS INNOVATION LDA',...
# ...              ...                                                ...
# 1929865     10473924  [{'description': 'Patrícia Daniela Ferreira Pe...
# 1930147     10898883  [{'description': 'Vasco Miguel tavares', 'nif'...
# 1930190     10518886  [{'description': 'Berenice Gomes Vila', 'nif':...
# 1930254     10518935  [{'description': 'Sofia Alexandra Silva Jesus ...
# 1930985     10661871  [{'description': 'JM RIBEIRO e ASSOCIADOS SROC...
#
# [918 rows x 2 columns]

# %% [markdown]
# Existe, 918 casos em que está em falta um nif ou uma description, por isso vamos eliminar estes casos:

# %%
# manter só os casos em que todos os contestants têm description e nif
concursos_publicos = concursos_publicos.loc[mask_ok].copy()

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**contracted**</span> <a id='Data-Types'></a>

# %%
counts = concursos_publicos["contracted"].apply(lambda x: len(x) if isinstance(x, (list, np.ndarray)) else 0)
counts.value_counts().sort_index()
# Out:
# contracted
# 1     129347
# 2       1508
# 3        376
# 4        178
# 5        150
# 6         70
# 7         47
# 8         32
# 9         20
# 10        18
# 11        14
# 12        13
# 13        14
# 14        11
# 15         2
# 17         2
# 18         4
# 19         2
# 20        10
# 23         1
# 24         1
# 26         2
# 27         1
# 29         2
# 64         1
# Name: count, dtype: int64

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**contracting_agency**</span> <a id='Data-Types'></a>

# %%
counts = concursos_publicos["contracting_agency"].apply(lambda x: len(x) if isinstance(x, (list, np.ndarray)) else 0)
counts.value_counts().sort_index()
# Out:
# contracting_agency
# 1     131752
# 2         54
# 3          3
# 4          1
# 5          6
# 6          1
# 7          1
# 9          1
# 11         1
# 12         1
# 16         1
# 17         2
# 30         1
# 37         1
# Name: count, dtype: int64

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**initial_price and final_price**</span> <a id='Data-Types'></a>

# %% [markdown]
# Now we will merge the columns `initial_price` and `final_price` into a column named `price` that representes the final adjudicated value (prefer final_price when available, otherwise fall back to initial_price):

# %%
# Merge initial_price and final_price into one column
concursos_publicos["price"] = concursos_publicos["final_price"].fillna(concursos_publicos["initial_price"])

# Drop the old columns if you don't need them anymore
concursos_publicos.drop(columns=["initial_price", "final_price"], inplace=True)

# %% [markdown]
# Now we will eliminate the rows that have **negatice prices**:

# %%
# Remove lines with price negative values
concursos_publicos = concursos_publicos[concursos_publicos['price'] > 0]
concursos_publicos.shape
# Out:
# (130136, 10)

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**execution_deadline**</span> <a id='Data-Types'></a>

# %% [markdown]
# Agora vamos analisar a coluna `execution_deadline`:

# %%
concursos_publicos['execution_deadline'].max()
# Out:
# 194667

# %%
col = ['execution_deadline']
plot_histograms(concursos_publicos,col, 1, 1)

# %% [markdown]
# Depois de analisar a sua distribuição, concluímos que existem casos de execution_deadline demasiado elevados, vamos redifinir um valor máximo de 6000 dias (aproximadamente 16 anos) e excluir os valores que estão acima desse limite.

# %%
concursos_publicos = concursos_publicos[concursos_publicos["execution_deadline"] < 6000]

# %%
concursos_publicos.shape
# Out:
# (130021, 10)

# %%
col = ['execution_deadline']
plot_histograms(concursos_publicos,col, 1, 1)

# %%
concursos_publicos.drop(columns=["execution_deadline"], inplace=True)

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**assembling contestants_name and contestants_nif**</span> <a id='Data-Types'></a>

# %%
def get_contestants_names(cell):
    if isinstance(cell, dict): cell = [cell]
    if isinstance(cell, (list, np.ndarray)):
        vals = [d.get('description') for d in cell if isinstance(d, dict) and d.get('description')]
        return vals  
    return []

def get_contestants_nifs(cell):
    if isinstance(cell, dict): cell = [cell]
    if isinstance(cell, (list, np.ndarray)):
        vals = [str(d.get('nif')) for d in cell if isinstance(d, dict) and d.get('nif') is not None]
        return vals
    return []

# %%
concursos_publicos.loc[:, 'contestants_name'] = concursos_publicos['contestants'].apply(get_contestants_names)
concursos_publicos.loc[:, 'contestants_nif']  = concursos_publicos['contestants'].apply(get_contestants_nifs)

# %% [markdown]
# Now we will check if all the contestants_nifs are valid and remove invalid contestants_nifs:

# %%
# 9 digits, starts with 5-9, and exclude 999999999
pt_nif = re.compile(r'^(?!999999999)[5-9]\d{8}$')

def to_seq(x):
    if isinstance(x, np.ndarray): return x.tolist()
    if isinstance(x, list):       return x
    if pd.isna(x) or x is None:   return []
    return [x]

def all_nifs_valid(nifs):
    seq = to_seq(nifs)
    if not seq:           # para excluir linhas sem NIFs
        return False
    for v in seq:
        s = str(v).strip()
        if not pt_nif.fullmatch(s):
            return False
    return True

# máscara: todos os NIFs da célula são válidos
mask_all_valid = concursos_publicos["contestants_nif"].apply(all_nifs_valid)

print("Linhas com todos os NIFs válidos:", int(mask_all_valid.sum()))
print("Total de linhas:", len(concursos_publicos))

# manter só essas linhas
concursos_publicos = concursos_publicos.loc[mask_all_valid].copy()
# Out:
# Linhas com todos os NIFs válidos: 119316
# Total de linhas: 130021

# %%
concursos_publicos.drop(columns=["contestants"], inplace=True)

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**assembling contracted_name and contracted_nif**</span> <a id='Data-Types'></a>

# %%
def get_contracted_name(cell):
    if isinstance(cell, (list, np.ndarray)) and len(cell) > 0 and isinstance(cell[0], dict):
        return cell[0].get('description')
    return None

def get_contracted_nif(cell):
    if isinstance(cell, (list, np.ndarray)) and len(cell) > 0 and isinstance(cell[0], dict):
        return cell[0].get('nif')
    return None

# %%
concursos_publicos.loc[:, 'contracted_name'] = concursos_publicos['contracted'].apply(get_contracted_name)
concursos_publicos.loc[:, 'contracted_nif']  = concursos_publicos['contracted'].apply(get_contracted_nif)

# %% [markdown]
# Now we will check if all the contracted_nifs are valid:

# %%
# 9 digits, starts with 5-9, and exclude 999999999
pt_nif = re.compile(r'^(?!999999999)[5-9]\d{8}$')

s = concursos_publicos['contracted_nif'].astype(str).str.strip()
mask_valid = s.str.fullmatch(pt_nif)

num_valid = mask_valid.sum()
total_non_null = concursos_publicos['contracted_nif'].notna().sum()
pct_valid = (num_valid / total_non_null * 100) if total_non_null else 0

print(f"Valid Portuguese NIFs: {num_valid}")
print(f"Out of {total_non_null} non-null entries → {pct_valid:.1f}% valid")
# Out:
# Valid Portuguese NIFs: 119241
# Out of 119316 non-null entries → 99.9% valid

# %%
# Drop das linhas inválidas
invalid_idx = concursos_publicos.index[~mask_valid]
concursos_publicos.drop(index=invalid_idx, inplace=True)

# Verifica o resultado
print(f"Linhas originais: {len(concursos_publicos) + len(invalid_idx)}")
print(f"Linhas mantidas:   {len(concursos_publicos)}")
# Out:
# Linhas originais: 119316
# Linhas mantidas:   119241

# %%
concursos_publicos.drop(columns=["contracted"], inplace=True)

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**assembling contracting_agency_name and contracting_agency_nif**</span> <a id='Data-Types'></a>

# %%
def get_contracting_agency_name(cell):
    if isinstance(cell, (list, np.ndarray)) and len(cell) > 0 and isinstance(cell[0], dict):
        return cell[0].get('description')
    return None

def get_contracting_agency_nif(cell):
    if isinstance(cell, (list, np.ndarray)) and len(cell) > 0 and isinstance(cell[0], dict):
        return cell[0].get('nif')
    return None

# %%
concursos_publicos.loc[:, 'contracting_agency_name'] = concursos_publicos['contracting_agency'].apply(get_contracting_agency_name)
concursos_publicos.loc[:, 'contracting_agency_nif']  = concursos_publicos['contracting_agency'].apply(get_contracting_agency_nif)

# %% [markdown]
# Now we will check if all the contracting_agency_nifs are valid:

# %%
# 9 digits, starts with 5-9, and exclude 999999999
pt_nif = re.compile(r'^(?!999999999)[5-9]\d{8}$')

s = concursos_publicos['contracting_agency_nif'].astype(str).str.strip()
mask_valid = s.str.fullmatch(pt_nif)

num_valid = mask_valid.sum()
total_non_null = concursos_publicos['contracting_agency_nif'].notna().sum()
pct_valid = (num_valid / total_non_null * 100) if total_non_null else 0

print(f"Valid Portuguese NIFs: {num_valid}")
print(f"Out of {total_non_null} non-null entries → {pct_valid:.1f}% valid")
# Out:
# Valid Portuguese NIFs: 119241
# Out of 119241 non-null entries → 100.0% valid

# %% [markdown]
# They are all valied nifs.

# %%
concursos_publicos.drop(columns=["contracting_agency"], inplace=True)

# %% [markdown]
# ##### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**execution_location**</span> <a id='Data-Types'></a>

# %% [markdown]
# Para cada contrato vamos dividir a localização em país, distrito e município de execução:

# %%
def _uniq_preserve(seq):
    """Remove duplicates, preserve order, ignore empty/NaN."""
    return list(OrderedDict.fromkeys([x for x in seq if pd.notna(x) and x != ""]))

def parse_exec_loc(val):
    # Expect val to be a numpy array of dicts
    if isinstance(val, (list, np.ndarray)):
        countries      = _uniq_preserve([d.get("country")      for d in val if isinstance(d, dict)])
        districts      = _uniq_preserve([d.get("district")     for d in val if isinstance(d, dict)])
        municipalities = _uniq_preserve([d.get("municipality") for d in val if isinstance(d, dict)])

        return pd.Series([
            ", ".join(countries) if countries else pd.NA,
            ", ".join(districts) if districts else pd.NA,
            ", ".join(municipalities) if municipalities else pd.NA
        ], index=["execution_country","execution_district","execution_municipality"])

    # if not array/list, return NAs
    return pd.Series([pd.NA, pd.NA, pd.NA],
                     index=["execution_country","execution_district","execution_municipality"])

# Apply
concursos_publicos[["execution_country","execution_district","execution_municipality"]] = (
    concursos_publicos["execution_location"].apply(parse_exec_loc)
)

# %% [markdown]
# Agora vamos ver quantas localizações temos por contrato:

# %%
counts = concursos_publicos["execution_location"].apply(lambda x: len(x) if 
                                                        isinstance(x, (list, np.ndarray)) else 0)
counts.value_counts().sort_index()
# Out:
# execution_location
# 1     109763
# 2       5178
# 3       1713
# 4        875
# 5        294
# 6        258
# 7        359
# 8        181
# 9         86
# 10       147
# 11        87
# 12        62
# 13        38
# 14        38
# 15        12
# 16        12
# 17        17
# 18        19
# 19         4
# 20        20
# 21         4
# 22        13
# 23         4
# 24         1
# 25         2
# 26         3
# 27         3
# 28         1
# 29         1
# 30         7
# 31         5
# 33         5
# 35        14
# 37         3
# 39         1
# 46         1
# 57         5
# 59         1
# 61         1
# 81         3
# Name: count, dtype: int64

# %%
concursos_publicos[["execution_location","execution_country", "execution_district", "execution_municipality"]]
# Out:
#                                         execution_location execution_country  \
# 73146    [{'country': 'Portugal', 'district': 'Lisboa',...          Portugal
# 73764    [{'country': 'Portugal', 'district': 'Leiria',...          Portugal
# 78646    [{'country': 'Portugal', 'district': 'Lisboa',...          Portugal
# 124563   [{'country': 'Portugal', 'district': 'Lisboa',...          Portugal
# 125322   [{'country': 'Portugal', 'district': 'Lisboa',...          Portugal
# ...                                                    ...               ...
# 1931273  [{'country': 'Portugal', 'district': 'Lisboa',...          Portugal
# 1931281  [{'country': 'Portugal', 'district': 'Setubal'...          Portugal
# 1931283  [{'country': 'Portugal', 'district': 'Braga', ...          Portugal
# 1931286  [{'country': 'Portugal', 'district': 'Aveiro',...          Portugal
# 1931289  [{'country': 'Portugal', 'district': 'Lisboa',...          Portugal
#
#         execution_district  execution_municipality
# 73146               Lisboa           Torres Vedras
# 73764               Leiria                  Leiria
# 78646               Lisboa                  Lisboa
# 124563              Lisboa  Sobral de Monte Agraco
# 125322              Lisboa                  Oeiras
# ...                    ...                     ...
# 1931273             Lisboa                  Lisboa
# 1931281            Setubal                  Almada
# 1931283              Braga                   Braga
# 1931286             Aveiro                  Aveiro
# 1931289             Lisboa                  Sintra
#
# [119241 rows x 4 columns]

# %% [markdown]
# Temos 11% de missing values no execution_district e 10% de missing values no execution_municipality, vamos remover as rows a que pertencem:

# %%
concursos_publicos.dropna(subset=["execution_country", "execution_district", "execution_municipality"], inplace=True)

# %%
concursos_publicos.shape
# Out:
# (105064, 15)

# %% [markdown]
# Para facilitar a busca por distritos e cidade vamos apenas manter as linhas com apenas 1 district e 1 municipio.

# %%
# Filtering the rows that only have 
concursos_publicos = concursos_publicos[(concursos_publicos['execution_district'].str.count(',') < 1)
                                        & (concursos_publicos['execution_municipality'].str.count(',') < 1)]

# %%
concursos_publicos.shape
# Out:
# (97947, 15)

# %%
concursos_publicos['execution_country'].value_counts()
# Out:
# execution_country
# Portugal                          97946
# Portugal, Portugal Continental        1
# Name: count, dtype: int64

# %% [markdown]
# Como o país é sempre Portugal, podemos excluir a coluna `execution_country` e `execution_location` para não ter informação repetida.

# %%
concursos_publicos.drop(columns=["execution_country","execution_location"], inplace=True)

# %%
concursos_publicos
# Out:
#          contract_id                  contract_type        cpvs signing_date  \
# 73146         875874       Aquisição de bens móveis  33171000-9   2010-05-12
# 73764         148916  Empreitadas de obras públicas  45000000-7   2010-07-30
# 78646        1076289          Aquisição de serviços  50000000-5   2010-11-25
# 124563        136321          Aquisição de serviços  90911200-8   2010-08-16
# 125322        600796          Aquisição de serviços  55520000-1   2010-03-25
# ...              ...                            ...         ...          ...
# 1931273     11088884  Empreitadas de obras públicas  45453100-8   2024-10-30
# 1931281     11088891          Aquisição de serviços  90910000-9   2024-05-29
# 1931283     11088904         Locação de bens móveis  39300000-5   2024-12-11
# 1931286     10813424          Aquisição de serviços  77314000-4   2024-07-09
# 1931289     11043018  Empreitadas de obras públicas  45211310-5   2024-11-08
#
#               price                                   contestants_name  \
# 73146      15450.00  [Dimor Lusitana,Lda, Anastácio Saldanha, Smith...
# 73764    1794202.51  [Tomás de Oliveira Empreiteiros, S.A, OIKOS – ...
# 78646    9779231.25  [TV CABO LISBOA, S.A., ONITELECOM - Infocomuni...
# 124563    103555.17  [Saniambiente Serviços Profissionais de Limpez...
# 125322     80655.00  [De Almeida Ribeiro Empreendimentos Hoteleiros...
# ...             ...                                                ...
# 1931273   403966.10  [Socodefil Lda, Aragão Seia Lda., Grandatlas C...
# 1931281     6182.64  [Servilimpe Limpezas Técnicas e Mecanizadas S....
# 1931283   529612.45  [Exemplus Internacional Ldª, Jetstand  Montage...
# 1931286   199000.00  [ECOAMBIENTE - SERVIÇOS E MEIO AMBIENTE S.A., ...
# 1931289     2000.00  [Margem Mítica-Manutenção e Reabilitação Unipe...
#
#                                            contestants_nif  \
# 73146    [500730741, 505804441, 507445937, 503413410, 5...
# 73764    [500285608, 501114998, 500821291, 500739749, 5...
# 78646    [503039063, 504073206, 502840757, 502604751, 5...
# 124563                   [506665836, 503024155, 502629428]
# 125322                   [504010298, 504551230, 500545103]
# ...                                                    ...
# 1931273                  [500742219, 509339387, 510199712]
# 1931281  [500246505, 516510657, 504458086, 515742503, 5...
# 1931283       [514999934, 503893684, 516665227, 506871541]
# 1931286  [502877472, 509482490, 505601800, 508827531, 5...
# 1931289                             [510800980, 513279849]
#
#                                            contracted_name contracted_nif  \
# 73146    Medicinália Cormédica-Comercialização Produtos...      500684324
# 73764                  MRG - ENGENHARIA E CONSTRUÇÃO, S.A.      500739749
# 78646    PT PRIME - Soluções Empresariais de Telecomuni...      502840757
# 124563                   Euromex - Facility Services, Lda.      502629428
# 125322                   Opção - Sociedade Hoteleira, Lda.      503875716
# ...                                                    ...            ...
# 1931273                          Grandatlas Construções SA      510199712
# 1931281                             Fine Facility Services      509418627
# 1931283      Multitendas-Comércio e Aluguer de Tendas S.A.      506871541
# 1931286  JUSTACOLINA- SERVIÇOS DE SILVICUTURA E EXPLORA...      514746408
# 1931289              Margarida Braz Borges Unipessoal Lda.      513279849
#
#                                    contracting_agency_name  \
# 73146                   Centro Hospitalar de Torres Vedras
# 73764    VALORLIS Valorização e Tratamento de Resíduos ...
# 78646                 Santa Casa da Misericórdia de Lisboa
# 124563                          Município de Torres Vedras
# 125322                                 Municipio de Oeiras
# ...                                                    ...
# 1931273                        Freguesia de Avenidas Novas
# 1931281            Ministério da Defesa Nacional - Marinha
# 1931283                                 Município de Braga
# 1931286             AdRA - Águas da Região de Aveiro S. A.
# 1931289                                Município de Sintra
#
#         contracting_agency_nif execution_district  execution_municipality
# 73146                505950413             Lisboa           Torres Vedras
# 73764                503811866             Leiria                  Leiria
# 78646                500745471             Lisboa                  Lisboa
# 124563               502173653             Lisboa  Sobral de Monte Agraco
# 125322               500745943             Lisboa                  Oeiras
# ...                        ...                ...                     ...
# 1931273              510856861             Lisboa                  Lisboa
# 1931281              600012662            Setubal                  Almada
# 1931283              506901173              Braga                   Braga
# 1931286              509107630             Aveiro                  Aveiro
# 1931289              500051062             Lisboa                  Sintra
#
# [97947 rows x 13 columns]

# %% [markdown]
# Agora nenhuma das colunas finais tem missing values.

# %% [markdown]
# Aqui vamos so alterar a ordem das colunas no dataframe:

# %%
cols = ["contract_id","contracted_name","contracted_nif","contestants_name","contestants_nif",
        "contracting_agency_name","contracting_agency_nif","price","signing_date",
        "execution_district","execution_municipality","contract_type", "cpvs"]
concursos_publicos = concursos_publicos[cols]

# %%
concursos_publicos
# Out:
#          contract_id                                    contracted_name  \
# 73146         875874  Medicinália Cormédica-Comercialização Produtos...
# 73764         148916                MRG - ENGENHARIA E CONSTRUÇÃO, S.A.
# 78646        1076289  PT PRIME - Soluções Empresariais de Telecomuni...
# 124563        136321                  Euromex - Facility Services, Lda.
# 125322        600796                  Opção - Sociedade Hoteleira, Lda.
# ...              ...                                                ...
# 1931273     11088884                          Grandatlas Construções SA
# 1931281     11088891                             Fine Facility Services
# 1931283     11088904      Multitendas-Comércio e Aluguer de Tendas S.A.
# 1931286     10813424  JUSTACOLINA- SERVIÇOS DE SILVICUTURA E EXPLORA...
# 1931289     11043018              Margarida Braz Borges Unipessoal Lda.
#
#         contracted_nif                                   contestants_name  \
# 73146        500684324  [Dimor Lusitana,Lda, Anastácio Saldanha, Smith...
# 73764        500739749  [Tomás de Oliveira Empreiteiros, S.A, OIKOS – ...
# 78646        502840757  [TV CABO LISBOA, S.A., ONITELECOM - Infocomuni...
# 124563       502629428  [Saniambiente Serviços Profissionais de Limpez...
# 125322       503875716  [De Almeida Ribeiro Empreendimentos Hoteleiros...
# ...                ...                                                ...
# 1931273      510199712  [Socodefil Lda, Aragão Seia Lda., Grandatlas C...
# 1931281      509418627  [Servilimpe Limpezas Técnicas e Mecanizadas S....
# 1931283      506871541  [Exemplus Internacional Ldª, Jetstand  Montage...
# 1931286      514746408  [ECOAMBIENTE - SERVIÇOS E MEIO AMBIENTE S.A., ...
# 1931289      513279849  [Margem Mítica-Manutenção e Reabilitação Unipe...
#
#                                            contestants_nif  \
# 73146    [500730741, 505804441, 507445937, 503413410, 5...
# 73764    [500285608, 501114998, 500821291, 500739749, 5...
# 78646    [503039063, 504073206, 502840757, 502604751, 5...
# 124563                   [506665836, 503024155, 502629428]
# 125322                   [504010298, 504551230, 500545103]
# ...                                                    ...
# 1931273                  [500742219, 509339387, 510199712]
# 1931281  [500246505, 516510657, 504458086, 515742503, 5...
# 1931283       [514999934, 503893684, 516665227, 506871541]
# 1931286  [502877472, 509482490, 505601800, 508827531, 5...
# 1931289                             [510800980, 513279849]
#
#                                    contracting_agency_name  \
# 73146                   Centro Hospitalar de Torres Vedras
# 73764    VALORLIS Valorização e Tratamento de Resíduos ...
# 78646                 Santa Casa da Misericórdia de Lisboa
# 124563                          Município de Torres Vedras
# 125322                                 Municipio de Oeiras
# ...                                                    ...
# 1931273                        Freguesia de Avenidas Novas
# 1931281            Ministério da Defesa Nacional - Marinha
# 1931283                                 Município de Braga
# 1931286             AdRA - Águas da Região de Aveiro S. A.
# 1931289                                Município de Sintra
#
#         contracting_agency_nif       price signing_date execution_district  \
# 73146                505950413    15450.00   2010-05-12             Lisboa
# 73764                503811866  1794202.51   2010-07-30             Leiria
# 78646                500745471  9779231.25   2010-11-25             Lisboa
# 124563               502173653   103555.17   2010-08-16             Lisboa
# 125322               500745943    80655.00   2010-03-25             Lisboa
# ...                        ...         ...          ...                ...
# 1931273              510856861   403966.10   2024-10-30             Lisboa
# 1931281              600012662     6182.64   2024-05-29            Setubal
# 1931283              506901173   529612.45   2024-12-11              Braga
# 1931286              509107630   199000.00   2024-07-09             Aveiro
# 1931289              500051062     2000.00   2024-11-08             Lisboa
#
#          execution_municipality                  contract_type        cpvs
# 73146             Torres Vedras       Aquisição de bens móveis  33171000-9
# 73764                    Leiria  Empreitadas de obras públicas  45000000-7
# 78646                    Lisboa          Aquisição de serviços  50000000-5
# 124563   Sobral de Monte Agraco          Aquisição de serviços  90911200-8
# 125322                   Oeiras          Aquisição de serviços  55520000-1
# ...                         ...                            ...         ...
# 1931273                  Lisboa  Empreitadas de obras públicas  45453100-8
# 1931281                  Almada          Aquisição de serviços  90910000-9
# 1931283                   Braga         Locação de bens móveis  39300000-5
# 1931286                  Aveiro          Aquisição de serviços  77314000-4
# 1931289                  Sintra  Empreitadas de obras públicas  45211310-5
#
# [97947 rows x 13 columns]

# %%
concursos_publicos.to_csv("Concursos_Públicos_impic.csv", index=False)

# %% [markdown]
# # <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Datasets do IMPIC**</span>
# **Objetivo:** Extrair os preços das bids

# %% [markdown]
# Informação relevante:
# - 1 procedimento pode ter vários lotes
# - 1 contrato <=> 1 lote

# %% [markdown]
# ## <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Anexo_vii**</span>

# %%
anexo_vii = pd.read_csv('C:/Users/beatr/Desktop/NOVA IMS/Bolsa de Investigação/RISKGUARD/impic_data/anexo_vii.csv', sep = ';')
anexo_vii
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_21548\2448121802.py:1: DtypeWarning: Columns (3,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   anexo_vii = pd.read_csv('C:/Users/beatr/Desktop/NOVA IMS/Bolsa de Investigação/RISKGUARD/impic_data/anexo_vii.csv', sep = ';')
#          Dados de base do procedimento  Número de lotes do procedimento  \
# 0                              1151622                                1
# 1                              1151622                                1
# 2                              1151622                                1
# 3                              1151622                                1
# 4                              1151622                                1
# ...                                ...                              ...
# 1258674                        7077279                                1
# 1258675                        7077279                                1
# 1258676                        7078955                                1
# 1258677                        7078955                                1
# 1258678                        7078955                                1
#
#          Preço base do lote em causa Número de ordem do lote em causa  \
# 0                          195000.01                                0
# 1                          195000.01                                0
# 2                          195000.01                                0
# 3                          195000.01                                0
# 4                          195000.01                                0
# ...                              ...                              ...
# 1258674                    110000.00                                0
# 1258675                    110000.00                                0
# 1258676                     19800.00                                0
# 1258677                     19800.00                                0
# 1258678                     19800.00                                0
#
#         Proposta Excluida?                        Motivo Exclusão de Proposta  \
# 0                      Não                                                NaN
# 1                      Não                                                NaN
# 2                      Não                                                NaN
# 3                      Não                                                NaN
# 4                      Não                                                NaN
# ...                    ...                                                ...
# 1258674                Não                                                NaN
# 1258675                Sim  Não apresentação de proposta nos termos em que...
# 1258676                Não                                                NaN
# 1258677                Não                                                NaN
# 1258678                Não                                                NaN
#
#         Código da proposta  Valor da proposta  Prazo de Execução  \
# 0                      0.0          135000.00               1096
# 1                      0.0          135750.00               1096
# 2                      0.0          139800.00               1096
# 3                      0.0          142500.00               1095
# 4                      0.0          149040.00               1095
# ...                    ...                ...                ...
# 1258674                0.0          101452.76                  0
# 1258675                0.0               0.00                210
# 1258676                0.0           18178.25                  0
# 1258677                0.0           19506.00                  0
# 1258678                0.0           19800.00                  0
#
#                                            Nome Contestant NIF Contestant
# 0          Econorte - Serviços e Produtos Ambientais, Lda.      504821270
# 1        Luthisa Lusitana de Tratamentos de Higiene, Un...      506012050
# 2                                          Anticimex, Lda.      501863087
# 3                              DST - Desinfecções Sul Tejo      501454543
# 4                                 Rentokil Initial Company      501351167
# ...                                                    ...            ...
# 1258674                             Dicajo Unipessoal Lda.      515330345
# 1258675  AECI, Arquitectura Construção e Empreendimento...      506294390
# 1258676                   Powershield Segurança Privada SA      510652581
# 1258677           Strong Charon , Soluções de Segurança SA      503257567
# 1258678                   KFORCEK- Segurança Privada, S.A.      514274557
#
# [1258679 rows x 11 columns]

# %%
anexo_vii['Proposta Excluida?'].value_counts()
# Out:
# Proposta Excluida?
# Não    1239420
# Sim      19259
# Name: count, dtype: int64

# %% [markdown]
# Vamos só manter propostas que nao foram excluídas:

# %%
anexo_vii = anexo_vii.loc[anexo_vii['Proposta Excluida?'].eq('Não')].copy()
print(len(anexo_vii))
# Out:
# 1239420

# %%
anexo_vii['Valor da proposta'].describe()
# Out:
# count    1.239420e+06
# mean     8.510540e+15
# std      8.983253e+18
# min     -1.958000e+05
# 25%      5.184000e+02
# 50%      7.866000e+03
# 75%      4.504125e+04
# max      1.000000e+22
# Name: Valor da proposta, dtype: float64

# %%
anexo_vii['Valor da proposta'].value_counts()
# Out:
# Valor da proposta
# 0.00         75422
# 1.00         18363
# 0.01         10223
# 3000.00       2721
# 15000.00      1724
#              ...
# 10603.28         1
# 85486.23         1
# 216247.68        1
# 210990.19        1
# 19506.00         1
# Name: count, Length: 450878, dtype: int64

# %% [markdown]
# Analisando os valores da coluna `Valor da proposta`, decidimos manter apenas propostas com valores superiores a 1 e inferiores a 1 milhão:

# %%
mask_valid = (anexo_vii['Valor da proposta'] >= 1) &  (anexo_vii['Valor da proposta'] <= 1000000)
anexo_vii = anexo_vii[mask_valid]

# %%
anexo_vii = anexo_vii[['Dados de base do procedimento','Valor da proposta','Nome Contestant',
                       'NIF Contestant','Número de lotes do procedimento', 
                       'Número de ordem do lote em causa']]

# %%
anexo_vii
# Out:
#          Dados de base do procedimento  Valor da proposta  \
# 0                              1151622          135000.00
# 1                              1151622          135750.00
# 2                              1151622          139800.00
# 3                              1151622          142500.00
# 4                              1151622          149040.00
# ...                                ...                ...
# 1258673                        7076694          149226.50
# 1258674                        7077279          101452.76
# 1258676                        7078955           18178.25
# 1258677                        7078955           19506.00
# 1258678                        7078955           19800.00
#
#                                            Nome Contestant NIF Contestant  \
# 0          Econorte - Serviços e Produtos Ambientais, Lda.      504821270
# 1        Luthisa Lusitana de Tratamentos de Higiene, Un...      506012050
# 2                                          Anticimex, Lda.      501863087
# 3                              DST - Desinfecções Sul Tejo      501454543
# 4                                 Rentokil Initial Company      501351167
# ...                                                    ...            ...
# 1258673                             MARTINS & FILHOS, S.A.      500968764
# 1258674                             Dicajo Unipessoal Lda.      515330345
# 1258676                   Powershield Segurança Privada SA      510652581
# 1258677           Strong Charon , Soluções de Segurança SA      503257567
# 1258678                   KFORCEK- Segurança Privada, S.A.      514274557
#
#          Número de lotes do procedimento Número de ordem do lote em causa
# 0                                      1                                0
# 1                                      1                                0
# 2                                      1                                0
# 3                                      1                                0
# 4                                      1                                0
# ...                                  ...                              ...
# 1258673                                1                                0
# 1258674                                1                                0
# 1258676                                1                                0
# 1258677                                1                                0
# 1258678                                1                                0
#
# [1116545 rows x 6 columns]

# %% [markdown]
# ## <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Lotes**</span>

# %%
lotes_impic_data = pd.read_csv('C:/Users/beatr/Desktop/NOVA IMS/Bolsa de Investigação/RISKGUARD/impic_data/lotes.csv', sep = ';')
lotes_impic_data
# Out:
#          IDAliasProc                          Descrição do Procedimento  \
# 0             600306  ATUALIZAÇÃO DE SOFTWARE E SUPORTE TÉCNICO SAP ...
# 1            1198383  PdS/Qualificação urbanística e tratamento do p...
# 2            1376519  Adução à Vidigueira - Conduta Adutora Vidiguei...
# 3            1385205                   5120007/2013 -Valvulas cardiacas
# 4            1390234                      REDES DE REPARAÇÃO DE HERNIAS
# ...              ...                                                ...
# 2906199      7022045                    68/4053/2023 Serviços Juridicos
# 2906200      7022051                  68/2385/2023 Serviço de Portagens
# 2906201      7022065                        78/569/2023 Gestão de Frota
# 2906202      7022131                                       HEMOCULTURA
# 2906203      7022134                                           CALDO GN
#
#          ContractID                              Descrição do Contrato  \
# 0           4289342  ATUALIZAÇÃO DE SOFTWARE E SUPORTE TÉCNICO SAP ...
# 1           4836026  PdS/Qualificação urbanística e tratamento do p...
# 2           4450288  Empreitada de Adução à Vidigueira - Conduta Ad...
# 3           4534668          5120007/2013 - Valvulas cardiacas e aneis
# 4           4710917       AD 0615-2015 REDES PARA REPARAÇÃO DE HÉRNIAS
# ...             ...                                                ...
# 2906199    10689723                    68/4053/2023 Serviços Juridicos
# 2906200    10689728                  68/2385/2023 Serviço de Portagens
# 2906201    10689749                        78/569/2023 Gestão de Frota
# 2906202    10689820                              81784723 HEMOCULTURA
# 2906203    10689823                                  81569423 CALDO GN
#
#                                Breve Descrição do Contrato  Preço Contratual  \
# 0        ATUALIZAÇÃO DE SOFTWARE E SUPORTE TÉCNICO SAP ...         299399.25
# 1        PdS/Qualificação urbanística e tratamento do p...         154000.00
# 2        Empreitada de Adução à Vidigueira - Conduta Ad...         435000.00
# 3                                       Válvulas cardiacas        1491030.00
# 4             AD 0615-2015 REDES PARA REPARAÇÃO DE HÉRNIAS          10450.00
# ...                                                    ...               ...
# 2906199                    68/4053/2023 Serviços Juridicos          13200.00
# 2906200                  68/2385/2023 Serviço de Portagens          14536.15
# 2906201                        78/569/2023 Gestão de Frota           8316.00
# 2906202                                       HEMOCULTURA            7454.08
# 2906203                                           CALDO GN             87.56
#
#         Número de Ordem do Lote Designação do Lote  Valor do Lote
# 0                             0                NaN      330000.00
# 1                             0                NaN      204000.00
# 2                             0                NaN      725000.00
# 3                             0                NaN     1792012.50
# 4                             6             Lote 6        4200.00
# ...                         ...                ...            ...
# 2906199                       0                NaN       13200.00
# 2906200                       0                NaN       17560.00
# 2906201                       0                NaN        8316.00
# 2906202                       0                NaN        7454.08
# 2906203                       0                NaN          87.56
#
# [2906204 rows x 9 columns]

# %%
lotes_impic_data = lotes_impic_data[['IDAliasProc','ContractID','Preço Contratual', 
                                     'Número de Ordem do Lote','Valor do Lote']]
lotes_impic_data
# Out:
#          IDAliasProc  ContractID  Preço Contratual Número de Ordem do Lote  \
# 0             600306     4289342         299399.25                       0
# 1            1198383     4836026         154000.00                       0
# 2            1376519     4450288         435000.00                       0
# 3            1385205     4534668        1491030.00                       0
# 4            1390234     4710917          10450.00                       6
# ...              ...         ...               ...                     ...
# 2906199      7022045    10689723          13200.00                       0
# 2906200      7022051    10689728          14536.15                       0
# 2906201      7022065    10689749           8316.00                       0
# 2906202      7022131    10689820           7454.08                       0
# 2906203      7022134    10689823             87.56                       0
#
#          Valor do Lote
# 0            330000.00
# 1            204000.00
# 2            725000.00
# 3           1792012.50
# 4              4200.00
# ...                ...
# 2906199       13200.00
# 2906200       17560.00
# 2906201        8316.00
# 2906202        7454.08
# 2906203          87.56
#
# [2906204 rows x 5 columns]

# %% [markdown]
# ## <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Merge do dataset anexo_vii e lotes**</span>

# %%
merged = anexo_vii.merge(
    lotes_impic_data, 
    how='inner',
    left_on= ['Dados de base do procedimento', 'Número de ordem do lote em causa'],
    right_on=['IDAliasProc', 'Número de Ordem do Lote']
)

# %%
merged.shape
# Out:
# (874725, 11)

# %%
# Mudar o nome da coluna 'IDAliasProc'
merged = merged.rename(columns={'IDAliasProc': 'ProcedimentoID'})

# %%
# Organizar a ordem das colunas e eliminar colunas repetidas
merged_clean = merged[['ProcedimentoID', 'ContractID','Número de lotes do procedimento',
                            'Número de Ordem do Lote','Preço Contratual','Valor da proposta', 
                            'Valor do Lote', 'Nome Contestant', 'NIF Contestant']]

# %% [markdown]
# Agora vamos eliminar as rows que têm um `Preço Contratual` de 0.0:

# %%
merged_clean = merged_clean.loc[merged_clean['Preço Contratual'] != 0].copy()
print(merged_clean.shape)
# Out:
# (868963, 9)

# %% [markdown]
# Agora vamos verificar se todos os nifs dos contestants são válidos e dropar as rows com nifs inválidos:

# %%
# regra
pt_nif = re.compile(r'^(?!999999999)[5-9]\d{8}$')

def to_seq(x):
    if isinstance(x, np.ndarray): return x.tolist()
    if isinstance(x, list):       return x
    if pd.isna(x) or x is None:   return []
    return [x]

def all_nifs_valid(nifs):
    seq = to_seq(nifs)
    if not seq:           # se quiseres também excluir linhas sem NIFs
        return False
    for v in seq:
        s = str(v).strip()
        if not pt_nif.fullmatch(s):
            return False
    return True

# máscara: todos os NIFs da célula são válidos
mask_all_valid = merged_clean["NIF Contestant"].apply(all_nifs_valid)

print("Linhas com todos os NIFs válidos:", int(mask_all_valid.sum()))
print("Total de linhas:", len(merged_clean))

# manter só essas linhas
merged_clean = merged_clean.loc[mask_all_valid].copy()
# Out:
# Linhas com todos os NIFs válidos: 845217
# Total de linhas: 868963

# %%
merged_clean
# Out:
#         ProcedimentoID  ContractID  Número de lotes do procedimento  \
# 0              3508804     4783825                                1
# 1              3508804     4783825                                1
# 2              3508804     4783825                                1
# 3              3508804     4783825                                1
# 4              3508804     4783825                                1
# ...                ...         ...                              ...
# 874720         7019505    10686502                                1
# 874721         7020256    10687360                                1
# 874722         7020257    10687358                                1
# 874723         7021414    10689095                                1
# 874724         7021612    10689231                                1
#
#        Número de Ordem do Lote  Preço Contratual  Valor da proposta  \
# 0                            0           12900.0           13990.00
# 1                            0           12900.0           14379.12
# 2                            0           12900.0           15557.52
# 3                            0           12900.0           15840.00
# 4                            0           12900.0           16870.26
# ...                        ...               ...                ...
# 874720                       0           93550.0           93550.00
# 874721                       0            4000.0            4000.00
# 874722                       0           12935.9           12935.90
# 874723                       0           20501.0           20501.00
# 874724                       0           26975.0           26975.00
#
#         Valor do Lote                                    Nome Contestant  \
# 0            19000.00                       365 - segurança privada, lda
# 1            19000.00                    Anthea - Segurança Privada, Lda
# 2            19000.00           Strong Charon , Soluções de Segurança SA
# 3            19000.00                 Comansegur -  Segurança Privada SA
# 4            19000.00  SECURITAS - SERVIÇOS E TECNOLOGIA DE SEGURANÇA...
# ...               ...                                                ...
# 874720       93684.51                                     LIGALOTE, LDA.
# 874721        4000.00             Algardata, Sistemas Informáticos, S.A.
# 874722       12935.90             Algardata, Sistemas Informáticos, S.A.
# 874723       27000.00  PAECRO - PROJECTOS ANALISE ESTUDOS CONSTRUÇÃO ...
# 874724       36000.00  PAECRO - PROJECTOS ANALISE ESTUDOS CONSTRUÇÃO ...
#
#        NIF Contestant
# 0           507158148
# 1           508704758
# 2           503257567
# 3           503586579
# 4           500243719
# ...               ...
# 874720      509608540
# 874721      502420227
# 874722      502420227
# 874723      509377513
# 874724      509377513
#
# [845217 rows x 9 columns]

# %% [markdown]
# ## <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Dataset concursos públicos final**</span>

# %%
# Vamos buscar o dataset dos concursos_publicos que estivemos a limpar em cima
concursos_publicos = pd.read_csv("Concursos_Públicos_impic.csv")

# %% [markdown]
# Agora vamos expandir as listas de `contestants_name` e `contestants_nif` para que cada linha passe a ser um contestant no dataset dos concursos_publicos:

# %%
def to_list(x):
    """Converte valores em lista:
       - mantém listas; 
       - transforma strings tipo "['a','b']" em lista;
       - trata NaN como lista vazia."""
    if isinstance(x, list):
        return x
    if pd.isna(x):
        return []
    if isinstance(x, str):
        s = x.strip()
        # se parecer lista, tenta fazer parse seguro
        if s.startswith('[') and s.endswith(']'):
            try:
                return ast.literal_eval(s)
            except Exception:
                pass
        # caso contrário, devolve lista unitária
        return [x]
    if isinstance(x, tuple):
        return list(x)
    try:
        # ex: numpy array
        return list(x)
    except Exception:
        return [x]

# normalizar as colunas para listas
concursos_publicos['contestants_name'] = concursos_publicos['contestants_name'].apply(to_list)
concursos_publicos['contestants_nif']  = concursos_publicos['contestants_nif'].apply(to_list)

# emparelhar por posição
pairs = concursos_publicos.apply(
    lambda r: list(zip_longest(r['contestants_name'], r['contestants_nif'])),
    axis=1
)

# explodir e separar em duas colunas
concursos_publicos_c = concursos_publicos.copy()  # concursos_publicos_c, c de contestant
concursos_publicos_c = concursos_publicos_c.assign(_pairs=pairs).explode('_pairs', ignore_index=True)

concursos_publicos_c[['contestant_name', 'contestant_nif']] = pd.DataFrame(
    concursos_publicos_c['_pairs'].tolist(), index=concursos_publicos_c.index
)

# limpeza final
concursos_publicos_c = concursos_publicos_c.drop(columns=['_pairs', 'contestants_name', 'contestants_nif'])

# %%
concursos_publicos_c
# Out:
#         contract_id                                    contracted_name  \
# 0            875874  Medicinália Cormédica-Comercialização Produtos...
# 1            875874  Medicinália Cormédica-Comercialização Produtos...
# 2            875874  Medicinália Cormédica-Comercialização Produtos...
# 3            875874  Medicinália Cormédica-Comercialização Produtos...
# 4            875874  Medicinália Cormédica-Comercialização Produtos...
# ...             ...                                                ...
# 727295     10813424  JUSTACOLINA- SERVIÇOS DE SILVICUTURA E EXPLORA...
# 727296     10813424  JUSTACOLINA- SERVIÇOS DE SILVICUTURA E EXPLORA...
# 727297     10813424  JUSTACOLINA- SERVIÇOS DE SILVICUTURA E EXPLORA...
# 727298     11043018              Margarida Braz Borges Unipessoal Lda.
# 727299     11043018              Margarida Braz Borges Unipessoal Lda.
#
#         contracted_nif                 contracting_agency_name  \
# 0            500684324      Centro Hospitalar de Torres Vedras
# 1            500684324      Centro Hospitalar de Torres Vedras
# 2            500684324      Centro Hospitalar de Torres Vedras
# 3            500684324      Centro Hospitalar de Torres Vedras
# 4            500684324      Centro Hospitalar de Torres Vedras
# ...                ...                                     ...
# 727295       514746408  AdRA - Águas da Região de Aveiro S. A.
# 727296       514746408  AdRA - Águas da Região de Aveiro S. A.
# 727297       514746408  AdRA - Águas da Região de Aveiro S. A.
# 727298       513279849                     Município de Sintra
# 727299       513279849                     Município de Sintra
#
#         contracting_agency_nif     price signing_date execution_district  \
# 0                    505950413   15450.0   2010-05-12             Lisboa
# 1                    505950413   15450.0   2010-05-12             Lisboa
# 2                    505950413   15450.0   2010-05-12             Lisboa
# 3                    505950413   15450.0   2010-05-12             Lisboa
# 4                    505950413   15450.0   2010-05-12             Lisboa
# ...                        ...       ...          ...                ...
# 727295               509107630  199000.0   2024-07-09             Aveiro
# 727296               509107630  199000.0   2024-07-09             Aveiro
# 727297               509107630  199000.0   2024-07-09             Aveiro
# 727298               500051062    2000.0   2024-11-08             Lisboa
# 727299               500051062    2000.0   2024-11-08             Lisboa
#
#        execution_municipality                  contract_type        cpvs  \
# 0               Torres Vedras       Aquisição de bens móveis  33171000-9
# 1               Torres Vedras       Aquisição de bens móveis  33171000-9
# 2               Torres Vedras       Aquisição de bens móveis  33171000-9
# 3               Torres Vedras       Aquisição de bens móveis  33171000-9
# 4               Torres Vedras       Aquisição de bens móveis  33171000-9
# ...                       ...                            ...         ...
# 727295                 Aveiro          Aquisição de serviços  77314000-4
# 727296                 Aveiro          Aquisição de serviços  77314000-4
# 727297                 Aveiro          Aquisição de serviços  77314000-4
# 727298                 Sintra  Empreitadas de obras públicas  45211310-5
# 727299                 Sintra  Empreitadas de obras públicas  45211310-5
#
#                                           contestant_name contestant_nif
# 0                                      Dimor Lusitana,Lda      500730741
# 1                                      Anastácio Saldanha      505804441
# 2                                     Smith & Nephew, Lda      507445937
# 3                     Coviden Portugal - Unipessoal, Lda.      503413410
# 4                       PMH-Produtos Médicos Hospitalares      502376899
# ...                                                   ...            ...
# 727295                                        FLOPONOR SA      503694479
# 727296                  PLANTEL SOBERANO - UNIPESSOAL LDA      516310127
# 727297               ECOREDE - ENGENHARIA E SERVIÇOS S.A.      508271754
# 727298  Margem Mítica-Manutenção e Reabilitação Unipes...      510800980
# 727299              Margarida Braz Borges Unipessoal Lda.      513279849
#
# [727300 rows x 13 columns]

# %%
concursos_publicos_final = concursos_publicos_c.merge(
    merged_clean, 
    how='inner',
    left_on= ['contract_id', 'contestant_nif'],
    right_on=['ContractID', 'NIF Contestant']
)

# %%
concursos_publicos_final.shape
# Out:
# (270451, 22)

# %%
# Reordenar as colunas e eliminar as colunas repetidas do merge
concursos_publicos_final = concursos_publicos_final[['ProcedimentoID','ContractID',
    'Número de lotes do procedimento','Número de Ordem do Lote','Preço Contratual','Valor da proposta',
    'Valor do Lote','Nome Contestant','NIF Contestant','contracted_name', 'contracted_nif',
    'contracting_agency_name','contracting_agency_nif','signing_date','execution_district',
    'execution_municipality','contract_type','cpvs']]

# %%
concursos_publicos_final
# Out:
#         ProcedimentoID  ContractID  Número de lotes do procedimento  \
# 0              3516148     5075548                                4
# 1              3516148     5075548                                4
# 2              3516148     5075548                                4
# 3              3532298     5915046                                2
# 4              3532298     5915046                                2
# ...                ...         ...                              ...
# 270446         6575396    10355144                               23
# 270447         6575396    10355144                               23
# 270448         6575396    10355144                               23
# 270449         6575396    10355144                               23
# 270450         6575396    10355144                               23
#
#        Número de Ordem do Lote  Preço Contratual  Valor da proposta  \
# 0                            4          39750.00           48759.00
# 1                            4          39750.00           46750.00
# 2                            4          39750.00           39750.00
# 3                            1         493488.15          303712.57
# 4                            2         493488.15          343621.26
# ...                        ...               ...                ...
# 270446                      25          19169.51            1708.44
# 270447                       6          19169.51            2824.80
# 270448                      15          19169.51            2894.30
# 270449                      27          19169.51            3539.88
# 270450                       1          19169.51           10678.40
#
#         Valor do Lote                                    Nome Contestant  \
# 0            48800.00               Siemens Healthcare, Unipessoal, Lda.
# 1            48800.00                        IBERDATA - Equipamentos, SA
# 2            48800.00                           PHILIPS PORTUGUESA, S.A.
# 3           283440.02  EUREST (PORTUGAL)-SOCIEDADE EUROPEIA DE RESTAU...
# 4           318049.36  EUREST (PORTUGAL)-SOCIEDADE EUROPEIA DE RESTAU...
# ...               ...                                                ...
# 270446        1919.60                                     Hanniel Pontes
# 270447        3174.00                                     Hanniel Pontes
# 270448        3252.00                                     Hanniel Pontes
# 270449        3977.40                                     Hanniel Pontes
# 270450       11998.20                                     Hanniel Pontes
#
#        NIF Contestant                                    contracted_name  \
# 0           507925173                                 Philips Portuguesa
# 1           501904921                                 Philips Portuguesa
# 2           500216843                                 Philips Portuguesa
# 3           500347506  ITAU - INSTITUTO TÉCNICO DE ALIMENTAÇÃO HUMANA...
# 4           500347506  ITAU - INSTITUTO TÉCNICO DE ALIMENTAÇÃO HUMANA...
# ...               ...                                                ...
# 270446      509198520                                     PoAviation Lda
# 270447      509198520                                     PoAviation Lda
# 270448      509198520                                     PoAviation Lda
# 270449      509198520                                     PoAviation Lda
# 270450      509198520                                     PoAviation Lda
#
#         contracted_nif                            contracting_agency_name  \
# 0            500216843  Centro Hospitalar Universitário Lisboa Central...
# 1            500216843  Centro Hospitalar Universitário Lisboa Central...
# 2            500216843  Centro Hospitalar Universitário Lisboa Central...
# 3            500142858                              Município de Sesimbra
# 4            500142858                              Município de Sesimbra
# ...                ...                                                ...
# 270446       507766822                   MARINHA - Instituto Hidrográfico
# 270447       507766822                   MARINHA - Instituto Hidrográfico
# 270448       507766822                   MARINHA - Instituto Hidrográfico
# 270449       507766822                   MARINHA - Instituto Hidrográfico
# 270450       507766822                   MARINHA - Instituto Hidrográfico
#
#         contracting_agency_nif signing_date execution_district  \
# 0                    508080142   2018-10-30             Lisboa
# 1                    508080142   2018-10-30             Lisboa
# 2                    508080142   2018-10-30             Lisboa
# 3                    501144218   2018-09-25            Setubal
# 4                    501144218   2018-09-25            Setubal
# ...                        ...          ...                ...
# 270446               600012662   2023-11-03            Setubal
# 270447               600012662   2023-11-03            Setubal
# 270448               600012662   2023-11-03            Setubal
# 270449               600012662   2023-11-03            Setubal
# 270450               600012662   2023-11-03            Setubal
#
#        execution_municipality             contract_type        cpvs
# 0                      Lisboa  Aquisição de bens móveis  33110000-4
# 1                      Lisboa  Aquisição de bens móveis  33110000-4
# 2                      Lisboa  Aquisição de bens móveis  33110000-4
# 3                    Sesimbra     Aquisição de serviços  55524000-9
# 4                    Sesimbra     Aquisição de serviços  55524000-9
# ...                       ...                       ...         ...
# 270446                 Almada  Aquisição de bens móveis  35613000-4
# 270447                 Almada  Aquisição de bens móveis  35613000-4
# 270448                 Almada  Aquisição de bens móveis  35613000-4
# 270449                 Almada  Aquisição de bens móveis  35613000-4
# 270450                 Almada  Aquisição de bens móveis  35613000-4
#
# [270451 rows x 18 columns]

# %% [markdown]
# `NOTA:` O dataset concursos_publicos_final não está ordenado por id de procedimento é por isso que não aparece todos os contratos relativos a cada procedimento seguidos.
#
# Por exemplo:

# %%
concursos_publicos_final[concursos_publicos_final['contracted_nif'] == 506705641]
# Out:
#         ProcedimentoID  ContractID  Número de lotes do procedimento  \
# 258530         6140016    10038500                                1
# 258531         6140016    10038500                                1
# 258532         6140016    10038500                                1
# 258533         6140016    10038500                                1
#
#        Número de Ordem do Lote  Preço Contratual  Valor da proposta  \
# 258530                       0          554352.0           703128.0
# 258531                       0          554352.0                1.0
# 258532                       0          554352.0           664710.0
# 258533                       0          554352.0           554352.0
#
#         Valor do Lote                                    Nome Contestant  \
# 258530       563316.0                 IMI-IMAGENS MEDICAS INTEGRADAS, SA
# 258531       563316.0                    Everglobal Medical Network, Lda
# 258532       563316.0  Dr. Campos Costa - Consultório de Tomografia C...
# 258533       563316.0                  ITM INSTITUTO DE TELEMEDICINA LDA
#
#        NIF Contestant                    contracted_name  contracted_nif  \
# 258530      501721037  ITM INSTITUTO DE TELEMEDICINA LDA       506705641
# 258531      515824585  ITM INSTITUTO DE TELEMEDICINA LDA       506705641
# 258532      502082429  ITM INSTITUTO DE TELEMEDICINA LDA       506705641
# 258533      506705641  ITM INSTITUTO DE TELEMEDICINA LDA       506705641
#
#                          contracting_agency_name  contracting_agency_nif  \
# 258530  Centro Hospitalar do Médio Ave, E. P. E.               508093937
# 258531  Centro Hospitalar do Médio Ave, E. P. E.               508093937
# 258532  Centro Hospitalar do Médio Ave, E. P. E.               508093937
# 258533  Centro Hospitalar do Médio Ave, E. P. E.               508093937
#
#        signing_date execution_district execution_municipality  \
# 258530   2023-02-16              Porto            Santo Tirso
# 258531   2023-02-16              Porto            Santo Tirso
# 258532   2023-02-16              Porto            Santo Tirso
# 258533   2023-02-16              Porto            Santo Tirso
#
#                 contract_type        cpvs
# 258530  Aquisição de serviços  85150000-5
# 258531  Aquisição de serviços  85150000-5
# 258532  Aquisição de serviços  85150000-5
# 258533  Aquisição de serviços  85150000-5

# %%
# Alterar o type da coluna Número de lotes do procedimento para Int64
concursos_publicos_final['Número de lotes do procedimento'] = concursos_publicos_final['Número de lotes do procedimento'].astype('Int64')

# %%
concursos_publicos_final['signing_date'] = pd.to_datetime(
    concursos_publicos_final['signing_date'])

print("Data mínima:", concursos_publicos_final['signing_date'].min())
print("Data máxima:", concursos_publicos_final['signing_date'].max())
# Out:
# Data mínima: 2018-06-26 00:00:00
# Data máxima: 2023-12-30 00:00:00

# %% [markdown]
# `NOTA:` Este dataset de concursos públicos final só tem records de 2018-06-26 a 2023-12-30, porque é o intervalo de tempo que temos com os valores das propostas do contestants.

# %%
concursos_publicos_final
# Out:
#         ProcedimentoID  ContractID  Número de lotes do procedimento  \
# 0              3516148     5075548                                4
# 1              3516148     5075548                                4
# 2              3516148     5075548                                4
# 3              3532298     5915046                                2
# 4              3532298     5915046                                2
# ...                ...         ...                              ...
# 270446         6575396    10355144                               23
# 270447         6575396    10355144                               23
# 270448         6575396    10355144                               23
# 270449         6575396    10355144                               23
# 270450         6575396    10355144                               23
#
#        Número de Ordem do Lote  Preço Contratual  Valor da proposta  \
# 0                            4          39750.00           48759.00
# 1                            4          39750.00           46750.00
# 2                            4          39750.00           39750.00
# 3                            1         493488.15          303712.57
# 4                            2         493488.15          343621.26
# ...                        ...               ...                ...
# 270446                      25          19169.51            1708.44
# 270447                       6          19169.51            2824.80
# 270448                      15          19169.51            2894.30
# 270449                      27          19169.51            3539.88
# 270450                       1          19169.51           10678.40
#
#         Valor do Lote                                    Nome Contestant  \
# 0            48800.00               Siemens Healthcare, Unipessoal, Lda.
# 1            48800.00                        IBERDATA - Equipamentos, SA
# 2            48800.00                           PHILIPS PORTUGUESA, S.A.
# 3           283440.02  EUREST (PORTUGAL)-SOCIEDADE EUROPEIA DE RESTAU...
# 4           318049.36  EUREST (PORTUGAL)-SOCIEDADE EUROPEIA DE RESTAU...
# ...               ...                                                ...
# 270446        1919.60                                     Hanniel Pontes
# 270447        3174.00                                     Hanniel Pontes
# 270448        3252.00                                     Hanniel Pontes
# 270449        3977.40                                     Hanniel Pontes
# 270450       11998.20                                     Hanniel Pontes
#
#        NIF Contestant                                    contracted_name  \
# 0           507925173                                 Philips Portuguesa
# 1           501904921                                 Philips Portuguesa
# 2           500216843                                 Philips Portuguesa
# 3           500347506  ITAU - INSTITUTO TÉCNICO DE ALIMENTAÇÃO HUMANA...
# 4           500347506  ITAU - INSTITUTO TÉCNICO DE ALIMENTAÇÃO HUMANA...
# ...               ...                                                ...
# 270446      509198520                                     PoAviation Lda
# 270447      509198520                                     PoAviation Lda
# 270448      509198520                                     PoAviation Lda
# 270449      509198520                                     PoAviation Lda
# 270450      509198520                                     PoAviation Lda
#
#         contracted_nif                            contracting_agency_name  \
# 0            500216843  Centro Hospitalar Universitário Lisboa Central...
# 1            500216843  Centro Hospitalar Universitário Lisboa Central...
# 2            500216843  Centro Hospitalar Universitário Lisboa Central...
# 3            500142858                              Município de Sesimbra
# 4            500142858                              Município de Sesimbra
# ...                ...                                                ...
# 270446       507766822                   MARINHA - Instituto Hidrográfico
# 270447       507766822                   MARINHA - Instituto Hidrográfico
# 270448       507766822                   MARINHA - Instituto Hidrográfico
# 270449       507766822                   MARINHA - Instituto Hidrográfico
# 270450       507766822                   MARINHA - Instituto Hidrográfico
#
#         contracting_agency_nif signing_date execution_district  \
# 0                    508080142   2018-10-30             Lisboa
# 1                    508080142   2018-10-30             Lisboa
# 2                    508080142   2018-10-30             Lisboa
# 3                    501144218   2018-09-25            Setubal
# 4                    501144218   2018-09-25            Setubal
# ...                        ...          ...                ...
# 270446               600012662   2023-11-03            Setubal
# 270447               600012662   2023-11-03            Setubal
# 270448               600012662   2023-11-03            Setubal
# 270449               600012662   2023-11-03            Setubal
# 270450               600012662   2023-11-03            Setubal
#
#        execution_municipality             contract_type        cpvs
# 0                      Lisboa  Aquisição de bens móveis  33110000-4
# 1                      Lisboa  Aquisição de bens móveis  33110000-4
# 2                      Lisboa  Aquisição de bens móveis  33110000-4
# 3                    Sesimbra     Aquisição de serviços  55524000-9
# 4                    Sesimbra     Aquisição de serviços  55524000-9
# ...                       ...                       ...         ...
# 270446                 Almada  Aquisição de bens móveis  35613000-4
# 270447                 Almada  Aquisição de bens móveis  35613000-4
# 270448                 Almada  Aquisição de bens móveis  35613000-4
# 270449                 Almada  Aquisição de bens móveis  35613000-4
# 270450                 Almada  Aquisição de bens móveis  35613000-4
#
# [270451 rows x 18 columns]

# %%
concursos_publicos_final = concursos_publicos_final.rename(
    columns={"ProcedimentoID": "procedure_id",
             "ContractID": "contract_id",
             "Número de lotes do procedimento": "num_lots",
             "Número de Ordem do Lote": "lot_number",
             "Preço Contratual": "contract_price",
             "Valor da proposta": "bid_value",
             "Valor do Lote": "lot_value",
             "Nome Contestant": "contestant_name",
             "NIF Contestant": "contestant_nif"
             })

# %%
concursos_publicos_final.columns
# Out:
# Index(['procedure_id', 'contract_id', 'num_lots', 'lot_number',
#        'contract_price', 'bid_value', 'lot_value', 'contestant_name',
#        'contestant_nif', 'contracted_name', 'contracted_nif',
#        'contracting_agency_name', 'contracting_agency_nif', 'signing_date',
#        'execution_district', 'execution_municipality', 'contract_type',
#        'cpvs'],
#       dtype='object')

# %% [markdown]
# ## <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Feature Engineering**</span>

# %% [markdown]
# #### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Screens**</span>
#
# | Screen                                                                 | Short name | Descrição detalhada |
# |-------------------------------------------------------------------------|------------|-----------------------|
# | Coefficient of Variation                                                | **CV**     | Mede a variabilidade relativa das propostas; cartéis tendem a submeter bids com pouca dispersão. |
# | Spread (diferença relativa entre bids)                                  | **SPD**    | Mede o espaço relativo entre a maior e a menor proposta dentro do concurso. |
# | Relative Difference between the two lowest bids                         | **DIFFP**  | Mede quão próximas estão as duas propostas mais baixas; conluio tende a produzir bids quase idênticas. |
# | Relative Distance                                                       | **RD**     | Mede a distante relativa do segundo concorrente ao vencedor, normalizado pela variabilidade das propostas perdidas. |
# | Kurtosis da distribuição de bids                                        | **KURT**   | Analisa caudas pesadas na distribuição das propostas, útil para identificar valores extremos incomuns. |
# | Skewness da distribuição de bids                                        | **SKEW**   | Mede a assimetria da distribuição das propostas, frequentemente alterada em casos de coordenação. |
# | Kolmogorov-Smirnov Test                                                 | **KSTEST** | Testa se a distribuição real dos bids diverge da distribuição esperada, indicando potencial manipulação. |

# %% [markdown]
# Criar um dataframe com as colunas importantes para futura análise:

# %%
nifs_por_contrato = (
    concursos_publicos_final
    .groupby("contract_id")["contestant_nif"]
    .apply(lambda x: sorted(set(x)))
    .reset_index(name="nifs_contestants"))

nifs_por_contrato

cols = [
    "contracted_nif",
    "signing_date",
    "execution_district",
    "execution_municipality",
    "contract_type",
    "cpvs"]

contrato_info = (
        concursos_publicos_final.groupby("contract_id")[cols]
      .agg({
          "contracted_nif": "first",
          "signing_date": "first",
          "execution_district": "first",
          "execution_municipality": "first",
          "contract_type": "first",
          "cpvs": "first"}))

# merge final
df_contrato = nifs_por_contrato.merge(contrato_info, on="contract_id", how="left")
df_contrato
# Out:
#        contract_id                                   nifs_contestants  \
# 0          4754387                  [503504564, 504723456, 507857542]
# 1          4783825  [500131210, 500243719, 501326456, 502332905, 5...
# 2          4817952                             [500553408, 501428119]
# 3          4818176                             [500553408, 501428119]
# 4          4818247                             [500553408, 501428119]
# ...            ...                                                ...
# 46584     10428562                  [501506543, 501895558, 503232785]
# 46585     10428564                                        [503480045]
# 46586     10428567                             [503480045, 510533515]
# 46587     10428588                  [500039720, 503232785, 510533515]
# 46588     10428649                                        [502867590]
#
#        contracted_nif signing_date execution_district execution_municipality  \
# 0           503504564   2018-08-09             Leiria         Marinha Grande
# 1           507011724   2018-08-01              Porto                  Porto
# 2           500553408   2018-09-07              Braga                  Braga
# 3           500553408   2018-09-07              Braga                  Braga
# 4           500553408   2018-09-07              Braga                  Braga
# ...               ...          ...                ...                    ...
# 46584       501895558   2023-12-12             Lisboa                 Lisboa
# 46585       503480045   2023-12-12             Lisboa                 Lisboa
# 46586       510533515   2023-12-12             Lisboa                 Lisboa
# 46587       500039720   2023-12-28             Lisboa                 Lisboa
# 46588       502867590   2023-12-28             Leiria                 Leiria
#
#                   contract_type        cpvs
# 0      Aquisição de bens móveis  09123000-7
# 1         Aquisição de serviços  79710000-4
# 2      Aquisição de bens móveis  44113700-2
# 3      Aquisição de bens móveis  44113700-2
# 4      Aquisição de bens móveis  44113700-2
# ...                         ...         ...
# 46584  Aquisição de bens móveis  33140000-3
# 46585  Aquisição de bens móveis  33140000-3
# 46586  Aquisição de bens móveis  33140000-3
# 46587  Aquisição de bens móveis  33140000-3
# 46588  Aquisição de bens móveis  15300000-1
#
# [46589 rows x 8 columns]

# %% [markdown]
# Este novo dataframe chamado `screens` com um contractID por linha será usado para criar uma coluna para cada screen:

# %%
screens = df_contrato.copy()

# %% [markdown]
# - **Coefficient of Variation (CV):** Mede a dispersão relativa entre as propostas.
#
# $$
# CV = \frac{\text{desvio padrão}}{\text{média das propostas}}
# $$
#
# Nos concursos públicos, casos de conluio tendem a apresentar coeficientes de variação (CV) muito baixos, tipicamente entre 0.00 e 0.08, enquanto concursos competitivos exibem CV mais altos (≈ 0.10–0.25).

# %%
# calcular o CV por contract_id
cv = (concursos_publicos_final
        .groupby('contract_id')['bid_value']
        .apply(lambda x: x.std() / x.mean()))

# adicionar ao screens, usando o contract_id como chave
screens['CV'] = screens['contract_id'].map(cv)

# %% [markdown]
# - **Spread (SPD):** Mede a diferença relativa entre a proposta mais cara e a mais barata.
#
# $$
# SPD = \frac{\text{bid mais alta} - \text{bid mais baixa}}{\text{bid mais baixa}}
# $$
#
# Nos concursos públicos, casos de conluio tendem a apresentar propostas mais próximas, ou seja, SPD baixo.
# Enquanto que concursos competitivos exibem mais dispersão entre propostas, ou seja, SPD alto.

# %%
# calcular o SPD por contract_id
spd = (concursos_publicos_final
        .groupby('contract_id')['bid_value']
        .apply(lambda x: (x.max() - x.min()) / x.min()))

# adicionar ao screens, usando o contract_id como chave
screens['SPD'] = screens['contract_id'].map(spd)

# %% [markdown]
# - **Relative Difference between the two lowest bids (DIFFP):** Mede o quão próximas estão as duas propostas mais baixas.
#
# $$
# DIFFP = \frac{\text{2ª menor proposta} - \text{menor proposta}}{\text{menor proposta}}
# $$
#
# Nos concursos públicos, casos de conluio tendem a apresentar bids muito próximas, ou seja, DIFFP baixo.
# Enquanto que concursos competitivos exibem bids mais dispersas, ou seja, DIFFP alto.

# %%
def diffp(x):
    x_sorted = x.sort_values()
    if len(x_sorted) < 2:
        return None  # não há duas propostas
    lowest = x_sorted.iloc[0]
    second_lowest = x_sorted.iloc[1]
    return (second_lowest - lowest) / lowest

# calcular o DIFFP por contract_id
diffp_vals = (
    concursos_publicos_final
        .groupby('contract_id')['bid_value']
        .apply(diffp)
)

# adicionar ao screens usando o contract_id como chave
screens['DIFFP'] = screens['contract_id'].map(diffp_vals)

# %% [markdown]
# - **Relative Distance (RD):** Mede a distante relativa do segundo concorrente ao vencedor, normalizado pela variabilidade das propostas perdidas.
#
# $$
# RD_t = \frac{b_{2,t} - b_{\min,t}}{sd_{\text{losingbids},t}}
# $$
#
# Nos concursos públicos, casos de conluio tendem a apresentar propostas muito próximas, ou seja, RD baixo.
# Enquanto que concursos competitivos exibem segunda bid mais distante, ou seja, RD alto.

# %%
def rd(x):
    # x é a série 'bid_value' de um contrato
    bids = x.sort_values()

    if len(bids) < 2:
        return None  # precisa de pelo menos duas propostas

    b_min = bids.iloc[0]
    b2 = bids.iloc[1]

    # losing bids = todas exceto a mais baixa
    losing = bids.iloc[1:]
    sd_losing = losing.std()

    if sd_losing == 0 or pd.isna(sd_losing):
        return None

    return (b2 - b_min) / sd_losing

# calcular RD por contract_id
rd_vals = (
    concursos_publicos_final
        .groupby('contract_id')['bid_value']
        .apply(rd)
)

# adicionar ao screens usando o contract_id como chave
screens['RD'] = screens['contract_id'].map(rd_vals)

# %% [markdown]
# - **Kurtosis (KURT):** Mede se a distribuição tem caudas mais pesadas ou mais leves do que o normal.
#
# $$
# Kurt(b_t) =
# \frac{n(n+1)}{(n-1)(n-2)(n-3)}
# \sum_{i=1}^{n} \left( \frac{b_{it} - \mu_t}{s_t} \right)^4
# -
# \frac{3(n-1)^2}{(n-2)(n-3)}
# $$
#
# Nos concursos públicos, diferentes tipos de conluio produzem formas diferentes de distribuição:
# - Cartéis com cover bids exageradas, exibem alta kurtosis;
# - Cartéis com coordenação de valores próximos, exibem baixa kurtosis.
#
# KURT anormal (muito alta OU muito baixa) é suspeito. KURT normal tende a ser competitivo.
#
# `NOTA:` Kurtosis can only be calculated for tenders with more than 3 bids, so in these cases we have a missing value. Result: 45989 (16%) values missing

# %%
def kurtosis_bids(x):
    # só faz sentido com pelo menos 4 bids
    if x.count() < 4:
        return np.nan
    # usar o método padrão de pandas
    return x.kurt()   # medida de caudas, suficiente para o screen

# calcular KURT por contract_id
kurt_vals = (
    concursos_publicos_final
        .groupby('contract_id')['bid_value']
        .apply(kurtosis_bids)
)

# adicionar ao screens usando o contract_id como chave
screens['KURT'] = screens['contract_id'].map(kurt_vals)

# %% [markdown]
# - **Skewness (SKEW):** Mede a assimetria da distribuição das bids por contrato.
#
# $$
# Skew(b_t) \;=\;
# \frac{n}{(n-1)(n-2)}
# \sum_{i=1}^{n} \left( \frac{b_{it} - \mu_t}{s_t} \right)^3
# $$
#
# - SKEW > 0 → cauda para a direita (mais bids altas)
# - SKEW < 0 → cauda para a esquerda (mais bids baixas)
#
# Bid rigging transforms the distribution of the bids in a more asymmetric distribution than in the competitive periods.
#
# `NOTA:` Skewness can only be computed for tenders with more than 2 bids, so in these cases we have a missing value. Result: 22988 (8%) values missing.

# %%
def skew_bids(x):
    # só faz sentido com pelo menos 3 bids
    if x.count() < 3:
        return np.nan
    # skewness padrão do pandas
    return x.skew()

# compute SKEW per contract_id
skew_vals = (
    concursos_publicos_final
        .groupby('contract_id')['bid_value']
        .apply(skew_bids)
)

# add to screens using contract_id as key
screens['SKEW'] = screens['contract_id'].map(skew_vals)

# %% [markdown]
# - **Kolmogorov-Smirnov Test (KSTEST):** Testa se a distribuição real dos bids diverge da distribuição esperada, indicando potencial manipulação.
#
# O KS compara: $ F_n(x) \quad \text{(CDF empírica das bids)} $
#
# com uma distribuição teórica (ex.: Normal(0,1)): $ F_0(x) $
#
# e mede o maior desvio: $ D_n = \sup_x |F_n(x) - F_0(x)| $
#
# Se as bids seguem um padrão competitivo, ($ D_n $) tende a ser **baixo**.
#
# KSTEST fica entre 0 e 1.
#
# Valores altos representam uma distribuição das bids muito diferente de uma forma “normal”, ou seja, mais anómalo (potencialmente suspeito).
#
# O kstest do SciPy calcula o maior desvio absoluto entre a CDF (Cumulative Distribution Function) empírica das bids e a CDF (Cumulative Distribution Function) teórica (normal, uniforme, etc.).
#
# > **O KSTEST identifica conluio porque mede o quanto a distribuição das propostas se afasta de um padrão competitivo natural; bids coordenadas, artificiais ou manipuladas distorcem essa distribuição, aumentando o valor do KS.**

# %%
def ks_bids(x):
    # precisa de pelo menos 3 bids para fazer algum sentido
    if x.count() < 3:
        return np.nan
    
    mu = x.mean()
    sigma = x.std()
    if sigma == 0 or np.isnan(sigma):
        return np.nan
    
    # normalizar bids
    z = (x - mu) / sigma
    
    # KS contra Normal(0,1)
    stat, pval = kstest(z, 'norm')
    return stat   

# calcular KSTEST por contract_id
ks_vals = (
    concursos_publicos_final
        .groupby('contract_id')['bid_value']
        .apply(ks_bids)
)

# adicionar ao screens usando o contract_id como chave
screens['KSTEST'] = screens['contract_id'].map(ks_vals)

# %% [markdown]
# Agora vamos eliminar as rows que têm missing values em alguma das screens:

# %%
screens = screens.dropna(axis=0, how='any')

# %%
screens
# Out:
#        contract_id                                   nifs_contestants  \
# 1          4783825  [500131210, 500243719, 501326456, 502332905, 5...
# 5          4825056  [501561358, 503554049, 508682002, 508836590, 5...
# 6          4827836  [503307483, 504020285, 508604460, 509189008, 5...
# 7          4834603       [500221103, 500424128, 502755814, 507581547]
# 8          4834611       [500424128, 502755814, 505483440, 507581547]
# ...            ...                                                ...
# 46576     10428459  [500701490, 500901694, 501642277, 503599093, 5...
# 46577     10428460  [500166099, 501333606, 503369489, 504870475, 5...
# 46578     10428464       [502117281, 502629428, 502771496, 514780355]
# 46586     10428567                             [503480045, 510533515]
# 46587     10428588                  [500039720, 503232785, 510533515]
#
#        contracted_nif signing_date execution_district execution_municipality  \
# 1           507011724   2018-08-01              Porto                  Porto
# 5           503554049   2018-09-04            Setubal                 Almada
# 6           504020285   2018-08-14             Leiria         Marinha Grande
# 7           500221103   2018-09-21             Lisboa                 Lisboa
# 8           500424128   2018-09-21             Lisboa                 Lisboa
# ...               ...          ...                ...                    ...
# 46576       500901694   2023-12-28             Aveiro                Espinho
# 46577       513718737   2023-12-22             Aveiro                 Ilhavo
# 46578       502629428   2023-12-27             Lisboa                 Loures
# 46586       510533515   2023-12-12             Lisboa                 Lisboa
# 46587       500039720   2023-12-28             Lisboa                 Lisboa
#
#                        contract_type        cpvs        CV        SPD  \
# 1              Aquisição de serviços  79710000-4  0.111163   0.350965
# 5           Aquisição de bens móveis  15000000-8  0.196546   0.514925
# 6              Aquisição de serviços  77314000-4  0.762421   9.000000
# 7           Aquisição de bens móveis  22112000-8  0.034250   0.081249
# 8           Aquisição de bens móveis  22112000-8  0.593060  14.145039
# ...                              ...         ...       ...        ...
# 46576       Aquisição de bens móveis  35121000-8  0.095072   0.282495
# 46577  Empreitadas de obras públicas  45232460-4  0.119184   0.335092
# 46578          Aquisição de serviços  90000000-7  0.172900   0.444219
# 46586       Aquisição de bens móveis  33140000-3  0.307192   0.810687
# 46587       Aquisição de bens móveis  33140000-3  0.903894  24.582329
#
#           DIFFP        RD      KURT      SKEW    KSTEST
# 1      0.027814  0.235109 -1.499507 -0.026671  0.134592
# 5      0.002985  0.012961 -3.049761 -0.366868  0.254944
# 6      2.000000  0.603023  0.553242  1.017670  0.275882
# 7      0.050044  3.163463  1.421385 -1.296284  0.246444
# 8      0.101310  0.039002  9.602099  2.718020  0.225003
# ...         ...       ...       ...       ...       ...
# 46576  0.030839  0.313414 -1.633944 -0.563764  0.238816
# 46577  0.018514  0.139065 -0.896794  0.851456  0.210851
# 46578  0.061191  0.291456  3.164927  1.726690  0.346329
# 46586  0.021505  0.051512 -5.292782  0.118826  0.296740
# 46587  0.646586  0.087796  1.473787  1.272965  0.206573
#
# [24141 rows x 15 columns]

# %% [markdown]
# ### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Summary Statistics**</span>

# %%
colunas_screens = ['CV', 'SPD', 'DIFFP', 'RD', 'KURT', 'SKEW', 'KSTEST']

summary = screens[colunas_screens].agg(
    ['count', 'mean', 'std', 'min', 'max']).T  # transpor para ficar com as screens nas linhas

summary.columns = ['Obs', 'Mean', 'Std. Dev.', 'Min', 'Max']

summary
# Out:
#             Obs          Mean     Std. Dev.           Min           Max
# CV      24141.0  5.194294e-01  5.089093e-01  1.344024e-16  8.062077e+00
# SPD     24141.0  4.396871e+04  1.432199e+05  0.000000e+00  9.999990e+05
# DIFFP   24141.0  1.361136e+04  6.853635e+04  0.000000e+00  9.455284e+05
# RD      24141.0  2.300161e+11  3.395736e+13  0.000000e+00  5.271294e+15
# KURT    24141.0  1.001170e+00  4.043489e+00 -6.000000e+00  1.566570e+02
# SKEW    24141.0  1.130769e-01  1.375773e+00 -3.917085e+00  1.146111e+01
# KSTEST  24141.0  2.874770e-01  8.477986e-02  5.842749e-02  8.381185e-01

# %%
num_cols = 2
num_rows = (len(colunas_screens) + num_cols - 1) // num_cols 
plot_histograms(screens, colunas_screens, num_rows, num_cols)

# %%
num_cols = 2
num_rows = (len(colunas_screens) + num_cols - 1) // num_cols 
plot_boxplots(screens, colunas_screens, num_rows, num_cols)
# Out:
#   Variable           Min  Lower Fence        Q1    Median          Q3  \
# 0       CV  1.344024e-16    -0.801328  0.127115  0.377770    0.746076
# 1      SPD  0.000000e+00  -457.163050  0.391923  2.054071  305.428571
# 2    DIFFP  0.000000e+00    -0.780694  0.021056  0.097778    0.555556
# 3       RD  0.000000e+00    -2.038193  0.017200  0.252584    1.387462
# 4     KURT -6.000000e+00    -8.579660 -1.470960  0.364803    3.268173
# 5     SKEW -3.917085e+00    -3.564987 -0.809586  0.077759    1.027348
# 6   KSTEST  5.842749e-02     0.040061  0.224030  0.283262    0.346676
#
#    Upper Fence           Max
# 0     1.674519  8.062077e+00
# 1   762.983544  9.999990e+05
# 2     1.357305  9.455284e+05
# 3     3.442856  5.271294e+15
# 4    10.376873  1.566570e+02
# 5     3.782749  1.146111e+01
# 6     0.530645  8.381185e-01

# %%
screens = screens.sort_values("RD").iloc[:-10]

# %%
num_cols = 2
num_rows = (len(colunas_screens) + num_cols - 1) // num_cols 
plot_boxplots(screens, colunas_screens, num_rows, num_cols)
# Out:
#   Variable           Min  Lower Fence        Q1    Median          Q3  \
# 0       CV  1.344024e-16    -0.801549  0.127122  0.377675    0.746236
# 1      SPD  0.000000e+00  -454.845705  0.391924  2.051909  303.883677
# 2    DIFFP  0.000000e+00    -0.778404  0.021053  0.097726    0.554023
# 3       RD  0.000000e+00    -2.031503  0.017186  0.252295    1.382978
# 4     KURT -6.000000e+00    -8.578883 -1.472774  0.363146    3.264631
# 5     SKEW -3.917085e+00    -3.562015 -0.808035  0.078523    1.027952
# 6   KSTEST  5.842749e-02     0.040176  0.224021  0.283194    0.346584
#
#    Upper Fence            Max
# 0     1.674907       8.062077
# 1   759.121307  999999.000000
# 2     1.353480  945528.400000
# 3     3.431667    4225.988364
# 4    10.370739     156.656961
# 5     3.781932      11.461113
# 6     0.530429       0.838118

# %%
screens['signing_date'] = pd.to_datetime(screens['signing_date'])

print("Data mínima:", screens['signing_date'].min())
print("Data máxima:", screens['signing_date'].max())
# Out:
# Data mínima: 2018-06-26 00:00:00
# Data máxima: 2023-12-30 00:00:00

# %% [markdown]
# ### <span style="background-color:#005e81; padding:5px; border-radius:5px;">**Standardization**</span>

# %%
# Selecionar apenas as screens:
features = ['CV', 'SPD', 'DIFFP', 'RD', 'KURT', 'SKEW','KSTEST']
df = screens[features].copy()

# %% [markdown]
# Vamos Standardizar com o StandardScaler (cada feature com média 0 e variância 1):

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
df_scaled = pd.DataFrame(df_scaled, columns=df.columns, index=df.index)
df_scaled
# Out:
#              CV       SPD     DIFFP         RD      KURT      SKEW    KSTEST
# 7633   0.823839  2.712676 -0.198291  -0.072645 -0.930043 -0.334704  0.377387
# 37883  1.428356 -0.266512 -0.198291  -0.072645 -0.939563  0.189293  0.855771
# 25683 -0.059544 -0.306851 -0.198291  -0.072645 -0.671198 -0.706098  1.496043
# 7581   1.249082  0.235626 -0.198291  -0.072645 -1.724249 -0.079407  0.227096
# 37865  0.316741 -0.306800 -0.198291  -0.072645 -0.287102  0.647801 -0.343620
# ...         ...       ...       ...        ...       ...       ...       ...
# 2660   0.289232  2.632346  5.931148  15.324348  0.741903 -1.537046  1.804080
# 18701  0.289223  0.738750  1.984241  22.086439  0.741918 -1.537059  1.808278
# 2283  -0.998153 -0.306871 -0.198290  63.426685  1.483820 -2.006594  2.558368
# 14866  0.289227  1.787730  4.179782  90.585839  0.741931 -1.537070  1.815694
# 1798  -1.007353 -0.306871 -0.198291  95.820575  1.483822 -2.006596  2.555443
#
# [24131 rows x 7 columns]

# %%
screens.to_csv("screens.csv", index=False) 
df_scaled.to_csv("screens_scaled.csv", index=False)
